# %%
# !pip freeze
# Out:
# asttokens==2.4.0
# backcall==0.2.0
# colorama==0.4.6
# comm==0.1.4
# debugpy==1.8.0
# decorator==5.1.1
# executing==2.0.0
# ipykernel==6.25.2
# ipython==8.16.1
# jedi==0.19.1
# jupyter_client==8.4.0
# jupyter_core==5.4.0
# matplotlib-inline==0.1.6
# nest-asyncio==1.5.8
# packaging==23.2
# parso==0.8.3
# pickleshare==0.7.5
# platformdirs==3.11.0
# prompt-toolkit==3.0.39
# psutil==5.9.5
# pure-eval==0.2.2
# Pygments==2.16.1
# python-dateutil==2.8.2
# pywin32==306
# pyzmq==25.1.1
# six==1.16.0
# stack-data==0.6.3
# tornado==6.3.3
# traitlets==5.11.2
# wcwidth==0.2.8

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting click (from nltk)
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.3.2-py3-none-any.whl (302 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Using cached regex-2023.10.3-cp311-cp311-win_amd64.whl (269 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: colorama in c:\users\yousuf\desktop\jar_mrk1\venv1\lib\site-packages (from click->nltk) (0.4.6)
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.1.7 joblib-1.3.2 nltk-3.8.1 regex-2023.10.3 tqdm-4.66.1
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import random
import pickle

import numpy as np
import pandas as pd
from nltk.tokenize import RegexpTokenizer

from tensorflow.keras.models import Sequential , load_model
from tensorflow.keras.layers import LSTM , Dense, Activation
from tensorflow.keras.optimizers import RMSprop

# %%
textdf = pd.read_csv("fake_or_real_news.csv")

# %%
textdf
# Out:
#          id                                              title  \
# 0      8476                       You Can Smell Hillary’s Fear
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2      3608        Kerry to go to Paris in gesture of sympathy
# 3     10142  Bernie supporters on Twitter erupt in anger ag...
# 4       875   The Battle of New York: Why This Primary Matters
# ...     ...                                                ...
# 6330   4490  State Department says it can't find emails fro...
# 6331   8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332   8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333   4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334   4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4     It's primary day in New York and front-runners...  REAL
# ...                                                 ...   ...
# 6330  The State Department told the Republican Natio...  REAL
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE
# 6332   Anti-Trump Protesters Are Tools of the Oligar...  FAKE
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...  REAL
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL
#
# [6335 rows x 4 columns]

# %%
text = list(textdf.text.values)
joined_text = " ".join(text)

# %%
len(joined_text)
# Out:
# 29826765

# %%
par_txt = joined_text[:10000]

# %%
tokenizer = RegexpTokenizer(r"\w+")
tokens = tokenizer.tokenize(par_txt.lower())

# %%
tokens
# Out:
# ['daniel',
#  'greenfield',
#  'a',
#  'shillman',
#  'journalism',
#  'fellow',
#  'at',
#  'the',
#  'freedom',
#  'center',
#  'is',
#  'a',
#  'new',
#  'york',
#  'writer',
#  'focusing',
#  'on',
#  'radical',
#  'islam',
#  'in',
#  'the',
#  'final',
#  'stretch',
#  'of',
#  'the',
#  'election',
#  'hillary',
#  'rodham',
#  'clinton',
#  'has',
#  'gone',
#  'to',
#  'war',
#  'with',
#  'the',
#  'fbi',
#  'the',
#  'word',
#  'unprecedented',
#  'has',
#  'been',
#  'thrown',
#  'around',
#  'so',
#  'often',
#  'this',
#  'election',
#  'that',
#  'it',
#  'ought',
#  'to',
#  'be',
#  'retired',
#  'but',
#  'it',
#  's',
#  'still',
#  'unprecedented',
#  'for',
#  'the',
#  'nominee',
#  'of',
#  'a',
#  'major',
#  'political',
#  'party',
#  'to',
#  'go',
#  'war',
#  'with',
#  'the',
#  'fbi',
#  'but',
#  'that',
#  's',
#  'exactly',
#  'what',
#  'hillary',
#  'and',
#  'her',
#  'people',
#  'have',
#  'done',
#  'coma',
#  'patients',
#  'just',
#  'waking',
#  'up',
#  'now',
#  'and',
#  'watching',
#  'an',
#  'hour',
#  'of',
#  'cnn',
#  'from',
#  'their',
#  'hospital',
#  'beds',
#  'would',
#  'assume',
#  'that',
#  'fbi',
#  'director',
#  'james',
#  'comey',
#  'is',
#  'hillary',
#  's',
#  'opponent',
#  'in',
#  'this',
#  'election',
#  'the',
#  'fbi',
#  'is',
#  'under',
#  'attack',
#  'by',
#  'everyone',
#  'from',
#  'obama',
#  'to',
#  'cnn',
#  'hillary',
#  's',
#  'people',
#  'have',
#  'circulated',
#  'a',
#  'letter',
#  'attacking',
#  'comey',
#  'there',
#  'are',
#  'currently',
#  'more',
#  'media',
#  'hit',
#  'pieces',
#  'lambasting',
#  'him',
#  'than',
#  'targeting',
#  'trump',
#  'it',
#  'wouldn',
#  't',
#  'be',
#  'too',
#  'surprising',
#  'if',
#  'the',
#  'clintons',
#  'or',
#  'their',
#  'allies',
#  'were',
#  'to',
#  'start',
#  'running',
#  'attack',
#  'ads',
#  'against',
#  'the',
#  'fbi',
#  'the',
#  'fbi',
#  's',
#  'leadership',
#  'is',
#  'being',
#  'warned',
#  'that',
#  'the',
#  'entire',
#  'left',
#  'wing',
#  'establishment',
#  'will',
#  'form',
#  'a',
#  'lynch',
#  'mob',
#  'if',
#  'they',
#  'continue',
#  'going',
#  'after',
#  'hillary',
#  'and',
#  'the',
#  'fbi',
#  's',
#  'credibility',
#  'is',
#  'being',
#  'attacked',
#  'by',
#  'the',
#  'media',
#  'and',
#  'the',
#  'democrats',
#  'to',
#  'preemptively',
#  'head',
#  'off',
#  'the',
#  'results',
#  'of',
#  'the',
#  'investigation',
#  'of',
#  'the',
#  'clinton',
#  'foundation',
#  'and',
#  'hillary',
#  'clinton',
#  'the',
#  'covert',
#  'struggle',
#  'between',
#  'fbi',
#  'agents',
#  'and',
#  'obama',
#  's',
#  'doj',
#  'people',
#  'has',
#  'gone',
#  'explosively',
#  'public',
#  'the',
#  'new',
#  'york',
#  'times',
#  'has',
#  'compared',
#  'comey',
#  'to',
#  'j',
#  'edgar',
#  'hoover',
#  'its',
#  'bizarre',
#  'headline',
#  'james',
#  'comey',
#  'role',
#  'recalls',
#  'hoover',
#  's',
#  'fbi',
#  'fairly',
#  'or',
#  'not',
#  'practically',
#  'admits',
#  'up',
#  'front',
#  'that',
#  'it',
#  's',
#  'spouting',
#  'nonsense',
#  'the',
#  'boston',
#  'globe',
#  'has',
#  'published',
#  'a',
#  'column',
#  'calling',
#  'for',
#  'comey',
#  's',
#  'resignation',
#  'not',
#  'to',
#  'be',
#  'outdone',
#  'time',
#  'has',
#  'an',
#  'editorial',
#  'claiming',
#  'that',
#  'the',
#  'scandal',
#  'is',
#  'really',
#  'an',
#  'attack',
#  'on',
#  'all',
#  'women',
#  'james',
#  'carville',
#  'appeared',
#  'on',
#  'msnbc',
#  'to',
#  'remind',
#  'everyone',
#  'that',
#  'he',
#  'was',
#  'still',
#  'alive',
#  'and',
#  'insane',
#  'he',
#  'accused',
#  'comey',
#  'of',
#  'coordinating',
#  'with',
#  'house',
#  'republicans',
#  'and',
#  'the',
#  'kgb',
#  'and',
#  'you',
#  'thought',
#  'the',
#  'vast',
#  'right',
#  'wing',
#  'conspiracy',
#  'was',
#  'a',
#  'stretch',
#  'countless',
#  'media',
#  'stories',
#  'charge',
#  'comey',
#  'with',
#  'violating',
#  'procedure',
#  'do',
#  'you',
#  'know',
#  'what',
#  's',
#  'a',
#  'procedural',
#  'violation',
#  'emailing',
#  'classified',
#  'information',
#  'stored',
#  'on',
#  'your',
#  'bathroom',
#  'server',
#  'senator',
#  'harry',
#  'reid',
#  'has',
#  'sent',
#  'comey',
#  'a',
#  'letter',
#  'accusing',
#  'him',
#  'of',
#  'violating',
#  'the',
#  'hatch',
#  'act',
#  'the',
#  'hatch',
#  'act',
#  'is',
#  'a',
#  'nice',
#  'idea',
#  'that',
#  'has',
#  'as',
#  'much',
#  'relevance',
#  'in',
#  'the',
#  'age',
#  'of',
#  'obama',
#  'as',
#  'the',
#  'tenth',
#  'amendment',
#  'but',
#  'the',
#  'cable',
#  'news',
#  'spectrum',
#  'quickly',
#  'filled',
#  'with',
#  'media',
#  'hacks',
#  'glancing',
#  'at',
#  'the',
#  'wikipedia',
#  'article',
#  'on',
#  'the',
#  'hatch',
#  'act',
#  'under',
#  'the',
#  'table',
#  'while',
#  'accusing',
#  'the',
#  'fbi',
#  'director',
#  'of',
#  'one',
#  'of',
#  'the',
#  'most',
#  'awkward',
#  'conspiracies',
#  'against',
#  'hillary',
#  'ever',
#  'if',
#  'james',
#  'comey',
#  'is',
#  'really',
#  'out',
#  'to',
#  'hurt',
#  'hillary',
#  'he',
#  'picked',
#  'one',
#  'hell',
#  'of',
#  'a',
#  'strange',
#  'way',
#  'to',
#  'do',
#  'it',
#  'not',
#  'too',
#  'long',
#  'ago',
#  'democrats',
#  'were',
#  'breathing',
#  'a',
#  'sigh',
#  'of',
#  'relief',
#  'when',
#  'he',
#  'gave',
#  'hillary',
#  'clinton',
#  'a',
#  'pass',
#  'in',
#  'a',
#  'prominent',
#  'public',
#  'statement',
#  'if',
#  'he',
#  'really',
#  'were',
#  'out',
#  'to',
#  'elect',
#  'trump',
#  'by',
#  'keeping',
#  'the',
#  'email',
#  'scandal',
#  'going',
#  'why',
#  'did',
#  'he',
#  'trash',
#  'the',
#  'investigation',
#  'was',
#  'he',
#  'on',
#  'the',
#  'payroll',
#  'of',
#  'house',
#  'republicans',
#  'and',
#  'the',
#  'kgb',
#  'back',
#  'then',
#  'and',
#  'playing',
#  'it',
#  'coy',
#  'or',
#  'was',
#  'it',
#  'a',
#  'sudden',
#  'development',
#  'where',
#  'vladimir',
#  'putin',
#  'and',
#  'paul',
#  'ryan',
#  'talked',
#  'him',
#  'into',
#  'taking',
#  'a',
#  'look',
#  'at',
#  'anthony',
#  'weiner',
#  's',
#  'computer',
#  'either',
#  'comey',
#  'is',
#  'the',
#  'most',
#  'cunning',
#  'fbi',
#  'director',
#  'that',
#  'ever',
#  'lived',
#  'or',
#  'he',
#  's',
#  'just',
#  'awkwardly',
#  'trying',
#  'to',
#  'navigate',
#  'a',
#  'political',
#  'mess',
#  'that',
#  'has',
#  'trapped',
#  'him',
#  'between',
#  'a',
#  'doj',
#  'leadership',
#  'whose',
#  'political',
#  'futures',
#  'are',
#  'tied',
#  'to',
#  'hillary',
#  's',
#  'victory',
#  'and',
#  'his',
#  'own',
#  'bureau',
#  'whose',
#  'apolitical',
#  'agents',
#  'just',
#  'want',
#  'to',
#  'be',
#  'allowed',
#  'to',
#  'do',
#  'their',
#  'jobs',
#  'the',
#  'only',
#  'truly',
#  'mysterious',
#  'thing',
#  'is',
#  'why',
#  'hillary',
#  'and',
#  'her',
#  'associates',
#  'decided',
#  'to',
#  'go',
#  'to',
#  'war',
#  'with',
#  'a',
#  'respected',
#  'federal',
#  'agency',
#  'most',
#  'americans',
#  'like',
#  'the',
#  'fbi',
#  'while',
#  'hillary',
#  'clinton',
#  'enjoys',
#  'a',
#  '60',
#  'unfavorable',
#  'rating',
#  'and',
#  'it',
#  's',
#  'an',
#  'interesting',
#  'question',
#  'hillary',
#  's',
#  'old',
#  'strategy',
#  'was',
#  'to',
#  'lie',
#  'and',
#  'deny',
#  'that',
#  'the',
#  'fbi',
#  'even',
#  'had',
#  'a',
#  'criminal',
#  'investigation',
#  'underway',
#  'instead',
#  'her',
#  'associates',
#  'insisted',
#  'that',
#  'it',
#  'was',
#  'a',
#  'security',
#  'review',
#  'the',
#  'fbi',
#  'corrected',
#  'her',
#  'and',
#  'she',
#  'shrugged',
#  'it',
#  'off',
#  'but',
#  'the',
#  'old',
#  'breezy',
#  'denial',
#  'approach',
#  'has',
#  'given',
#  'way',
#  'to',
#  'a',
#  'savage',
#  'assault',
#  'on',
#  'the',
#  'fbi',
#  'pretending',
#  'that',
#  'nothing',
#  'was',
#  'wrong',
#  'was',
#  'a',
#  'bad',
#  'strategy',
#  'but',
#  'it',
#  'was',
#  'a',
#  'better',
#  'one',
#  'that',
#  'picking',
#  'a',
#  'fight',
#  'with',
#  'the',
#  'fbi',
#  'while',
#  'lunatic',
#  'clinton',
#  'associates',
#  'try',
#  'to',
#  'claim',
#  'that',
#  'the',
#  'fbi',
#  'is',
#  'really',
#  'the',
#  'kgb',
#  'there',
#  'are',
#  'two',
#  'possible',
#  'explanations',
#  'hillary',
#  'clinton',
#  'might',
#  'be',
#  'arrogant',
#  'enough',
#  'to',
#  'lash',
#  'out',
#  'at',
#  'the',
#  'fbi',
#  'now',
#  'that',
#  'she',
#  'believes',
#  'that',
#  'victory',
#  'is',
#  'near',
#  'the',
#  'same',
#  'kind',
#  'of',
#  'hubris',
#  'that',
#  'led',
#  'her',
#  'to',
#  'plan',
#  'her',
#  'victory',
#  'fireworks',
#  'display',
#  'could',
#  'lead',
#  'her',
#  'to',
#  'declare',
#  'a',
#  'war',
#  'on',
#  'the',
#  'fbi',
#  'for',
#  'irritating',
#  'her',
#  'during',
#  'the',
#  'final',
#  'miles',
#  'of',
#  'her',
#  'campaign',
#  'but',
#  'the',
#  'other',
#  'explanation',
#  'is',
#  'that',
#  'her',
#  'people',
#  'panicked',
#  'going',
#  'to',
#  'war',
#  'with',
#  'the',
#  'fbi',
#  'is',
#  'not',
#  'the',
#  'behavior',
#  'of',
#  'a',
#  'smart',
#  'and',
#  'focused',
#  'presidential',
#  'campaign',
#  'it',
#  's',
#  'an',
#  'act',
#  'of',
#  'desperation',
#  'when',
#  'a',
#  'presidential',
#  'candidate',
#  'decides',
#  'that',
#  'her',
#  'only',
#  'option',
#  'is',
#  'to',
#  'try',
#  'and',
#  'destroy',
#  'the',
#  'credibility',
#  'of',
#  'the',
#  'fbi',
#  'that',
#  's',
#  'not',
#  'hubris',
#  'it',
#  's',
#  'fear',
#  'of',
#  'what',
#  'the',
#  'fbi',
#  'might',
#  'be',
#  'about',
#  'to',
#  'reveal',
#  'about',
#  'her',
#  'during',
#  'the',
#  'original',
#  'fbi',
#  'investigation',
#  'hillary',
#  'clinton',
#  'was',
#  'confident',
#  'that',
#  'she',
#  'could',
#  'ride',
#  'it',
#  'out',
#  'and',
#  'she',
#  'had',
#  'good',
#  'reason',
#  'for',
#  'believing',
#  'that',
#  'but',
#  'that',
#  'hillary',
#  'clinton',
#  'is',
#  'gone',
#  'in',
#  'her',
#  'place',
#  'is',
#  'a',
#  'paranoid',
#  'wreck',
#  'within',
#  'a',
#  'short',
#  'space',
#  'of',
#  'time',
#  'the',
#  'positive',
#  'clinton',
#  'campaign',
#  'promising',
#  'to',
#  'unite',
#  'the',
#  'country',
#  'has',
#  'been',
#  'replaced',
#  'by',
#  'a',
#  'desperate',
#  'and',
#  'flailing',
#  'operation',
#  'that',
#  'has',
#  'focused',
#  'all',
#  'its',
#  'energy',
#  'on',
#  'fighting',
#  'the',
#  'fbi',
#  'there',
#  's',
#  'only',
#  'one',
#  'reason',
#  'for',
#  'such',
#  'bizarre',
#  'behavior',
#  'the',
#  'clinton',
#  'campaign',
#  'has',
#  'decided',
#  'that',
#  'an',
#  'fbi',
#  'investigation',
#  'of',
#  'the',
#  'latest',
#  'batch',
#  'of',
#  'emails',
#  'poses',
#  'a',
#  'threat',
#  'to',
#  'its',
#  'survival',
#  'and',
#  'so',
#  'it',
#  's',
#  'gone',
#  'all',
#  'in',
#  'on',
#  'fighting',
#  'the',
#  'fbi',
#  'it',
#  's',
#  'an',
#  'unprecedented',
#  'step',
#  'born',
#  'of',
#  'fear',
#  'it',
#  's',
#  'hard',
#  'to',
#  'know',
#  'whether',
#  'that',
#  'fear',
#  'is',
#  'justified',
#  'but',
#  'the',
#  'existence',
#  'of',
#  'that',
#  'fear',
#  'already',
#  'tells',
#  'us',
#  'a',
#  'whole',
#  'lot',
#  'clinton',
#  'loyalists',
#  'rigged',
#  'the',
#  'old',
#  'investigation',
#  'they',
#  'knew',
#  'the',
#  'outcome',
#  'ahead',
#  ...]

# %%
unique_tokens = np.unique(tokens)

# %%
unique_token_index = {token: idx for idx,token in enumerate(unique_tokens)}

# %%
unique_token_index
# Out:
# {'2016': 0,
#  '2020': 1,
#  '5': 2,
#  '60': 3,
#  'a': 4,
#  'abc': 5,
#  'abcpolitics': 6,
#  'abedin': 7,
#  'about': 8,
#  'aboutface': 9,
#  'abuses': 10,
#  'accused': 11,
#  'accusing': 12,
#  'act': 13,
#  'ad': 14,
#  'admits': 15,
#  'ads': 16,
#  'afraid': 17,
#  'after': 18,
#  'afternoon': 19,
#  'against': 20,
#  'age': 21,
#  'agency': 22,
#  'agents': 23,
#  'ago': 24,
#  'ahead': 25,
#  'alive': 26,
#  'all': 27,
#  'allegations': 28,
#  'allies': 29,
#  'allowed': 30,
#  'already': 31,
#  'also': 32,
#  'amendment': 33,
#  'americans': 34,
#  'an': 35,
#  'and': 36,
#  'announced': 37,
#  'anthony': 38,
#  'any': 39,
#  'anywhere': 40,
#  'apolitical': 41,
#  'appearance': 42,
#  'appeared': 43,
#  'appearing': 44,
#  'appeaser': 45,
#  'approach': 46,
#  'are': 47,
#  'around': 48,
#  'arrogant': 49,
#  'article': 50,
#  'as': 51,
#  'asked': 52,
#  'assault': 53,
#  'assaulting': 54,
#  'assaults': 55,
#  'associates': 56,
#  'assume': 57,
#  'at': 58,
#  'attack': 59,
#  'attacked': 60,
#  'attacking': 61,
#  'away': 62,
#  'awkward': 63,
#  'awkwardly': 64,
#  'back': 65,
#  'backed': 66,
#  'bad': 67,
#  'badly': 68,
#  'batch': 69,
#  'bathroom': 70,
#  'be': 71,
#  'becoming': 72,
#  'beds': 73,
#  'been': 74,
#  'before': 75,
#  'behavior': 76,
#  'behind': 77,
#  'being': 78,
#  'belief': 79,
#  'believes': 80,
#  'believing': 81,
#  'better': 82,
#  'between': 83,
#  'bigger': 84,
#  'bigotry': 85,
#  'bizarre': 86,
#  'boldly': 87,
#  'born': 88,
#  'boston': 89,
#  'bragged': 90,
#  'breathing': 91,
#  'breeze': 92,
#  'breezy': 93,
#  'bribery': 94,
#  'bring': 95,
#  'bureau': 96,
#  'buried': 97,
#  'but': 98,
#  'by': 99,
#  'cable': 100,
#  'calling': 101,
#  'came': 102,
#  'campaign': 103,
#  'can': 104,
#  'candidate': 105,
#  'cards': 106,
#  'career': 107,
#  'careers': 108,
#  'carville': 109,
#  'center': 110,
#  'chances': 111,
#  'changed': 112,
#  'charge': 113,
#  'chilly': 114,
#  'circulated': 115,
#  'claim': 116,
#  'claimed': 117,
#  'claiming': 118,
#  'classified': 119,
#  'clearly': 120,
#  'clinton': 121,
#  'clintons': 122,
#  'clintonworld': 123,
#  'close': 124,
#  'closing': 125,
#  'cnn': 126,
#  'co': 127,
#  'collapsed': 128,
#  'colleagues': 129,
#  'column': 130,
#  'com': 131,
#  'coma': 132,
#  'come': 133,
#  'comey': 134,
#  'comment': 135,
#  'compared': 136,
#  'computer': 137,
#  'confident': 138,
#  'conservative': 139,
#  'conspiracies': 140,
#  'conspiracy': 141,
#  'continue': 142,
#  'control': 143,
#  'conviction': 144,
#  'coordinating': 145,
#  'corrected': 146,
#  'corruption': 147,
#  'could': 148,
#  'couldn': 149,
#  'countless': 150,
#  'country': 151,
#  'courage': 152,
#  'course': 153,
#  'cover': 154,
#  'covert': 155,
#  'cowardice': 156,
#  'coy': 157,
#  'cravenly': 158,
#  'credibility': 159,
#  'crime': 160,
#  'criminal': 161,
#  'cunning': 162,
#  'currently': 163,
#  'cycle': 164,
#  'damaging': 165,
#  'daniel': 166,
#  'day': 167,
#  'days': 168,
#  'debate': 169,
#  'decided': 170,
#  'decides': 171,
#  'declare': 172,
#  'declared': 173,
#  'declaring': 174,
#  'defending': 175,
#  'delicious': 176,
#  'democratic': 177,
#  'democrats': 178,
#  'denial': 179,
#  'deny': 180,
#  'desperate': 181,
#  'desperately': 182,
#  'desperation': 183,
#  'destroy': 184,
#  'development': 185,
#  'did': 186,
#  'didn': 187,
#  'digg': 188,
#  'director': 189,
#  'display': 190,
#  'dnc': 191,
#  'do': 192,
#  'doj': 193,
#  'don': 194,
#  'done': 195,
#  'dosed': 196,
#  'down': 197,
#  'during': 198,
#  'edgar': 199,
#  'editorial': 200,
#  'either': 201,
#  'elect': 202,
#  'election': 203,
#  'else': 204,
#  'email': 205,
#  'emailing': 206,
#  'emails': 207,
#  'endorsement': 208,
#  'energy': 209,
#  'enjoys': 210,
#  'enough': 211,
#  'entire': 212,
#  'especially': 213,
#  'establishment': 214,
#  'even': 215,
#  'ever': 216,
#  'every': 217,
#  'everyone': 218,
#  'exactly': 219,
#  'example': 220,
#  'exist': 221,
#  'existence': 222,
#  'explanation': 223,
#  'explanations': 224,
#  'explosively': 225,
#  'exposed': 226,
#  'exposing': 227,
#  'fairly': 228,
#  'fbi': 229,
#  'fear': 230,
#  'federal': 231,
#  'feigned': 232,
#  'fellow': 233,
#  'few': 234,
#  'fight': 235,
#  'fighting': 236,
#  'figurehead': 237,
#  'filled': 238,
#  'film': 239,
#  'final': 240,
#  'finding': 241,
#  'fire': 242,
#  'fireworks': 243,
#  'flailing': 244,
#  'focused': 245,
#  'focusing': 246,
#  'followed': 247,
#  'for': 248,
#  'form': 249,
#  'foundation': 250,
#  'freedom': 251,
#  'from': 252,
#  'front': 253,
#  'fundamental': 254,
#  'futures': 255,
#  'gasoline': 256,
#  'gave': 257,
#  'given': 258,
#  'glancing': 259,
#  'globe': 260,
#  'go': 261,
#  'going': 262,
#  'gone': 263,
#  'good': 264,
#  'google': 265,
#  'got': 266,
#  'greenfield': 267,
#  'hacks': 268,
#  'had': 269,
#  'happened': 270,
#  'hard': 271,
#  'harry': 272,
#  'has': 273,
#  'hatch': 274,
#  'hates': 275,
#  'have': 276,
#  'he': 277,
#  'head': 278,
#  'headline': 279,
#  'hell': 280,
#  'her': 281,
#  'here': 282,
#  'hillary': 283,
#  'him': 284,
#  'himself': 285,
#  'his': 286,
#  'hit': 287,
#  'home': 288,
#  'hoover': 289,
#  'hope': 290,
#  'hospital': 291,
#  'hour': 292,
#  'house': 293,
#  'how': 294,
#  'however': 295,
#  'https': 296,
#  'hubris': 297,
#  'huma': 298,
#  'hurt': 299,
#  'idea': 300,
#  'if': 301,
#  'illegal': 302,
#  'illegality': 303,
#  'impropriety': 304,
#  'in': 305,
#  'information': 306,
#  'insane': 307,
#  'insisted': 308,
#  'instant': 309,
#  'instead': 310,
#  'interesting': 311,
#  'intimidation': 312,
#  'into': 313,
#  'investigation': 314,
#  'investigators': 315,
#  'irritating': 316,
#  'is': 317,
#  'islam': 318,
#  'isn': 319,
#  'it': 320,
#  'its': 321,
#  'j': 322,
#  'james': 323,
#  'jobs': 324,
#  'journalism': 325,
#  'just': 326,
#  'justified': 327,
#  'keep': 328,
#  'keeping': 329,
#  'kgb': 330,
#  'kind': 331,
#  'knew': 332,
#  'know': 333,
#  'lambasting': 334,
#  'lash': 335,
#  'last': 336,
#  'latest': 337,
#  'lead': 338,
#  'leadership': 339,
#  'leave': 340,
#  'led': 341,
#  'left': 342,
#  'letter': 343,
#  'level': 344,
#  'lie': 345,
#  'lies': 346,
#  'like': 347,
#  'limp': 348,
#  'linkedin': 349,
#  'lit': 350,
#  'lived': 351,
#  'loaded': 352,
#  'locked': 353,
#  'lofty': 354,
#  'long': 355,
#  'longer': 356,
#  'look': 357,
#  'lot': 358,
#  'loyalists': 359,
#  'lunatic': 360,
#  'lynch': 361,
#  'made': 362,
#  'major': 363,
#  'make': 364,
#  'making': 365,
#  'man': 366,
#  'manages': 367,
#  'many': 368,
#  'match': 369,
#  'may': 370,
#  'meant': 371,
#  'media': 372,
#  'mess': 373,
#  'might': 374,
#  'miles': 375,
#  'misguided': 376,
#  'mob': 377,
#  'moment': 378,
#  'months': 379,
#  'moral': 380,
#  'more': 381,
#  'most': 382,
#  'msnbc': 383,
#  'much': 384,
#  'mysterious': 385,
#  'navigate': 386,
#  'near': 387,
#  'never': 388,
#  'new': 389,
#  'news': 390,
#  'nice': 391,
#  'no': 392,
#  'nobody': 393,
#  'nominee': 394,
#  'nonsense': 395,
#  'not': 396,
#  'nothing': 397,
#  'november': 398,
#  'now': 399,
#  'numerous': 400,
#  'obama': 401,
#  'of': 402,
#  'off': 403,
#  'often': 404,
#  'old': 405,
#  'on': 406,
#  'once': 407,
#  'one': 408,
#  'only': 409,
#  'operation': 410,
#  'opponent': 411,
#  'option': 412,
#  'or': 413,
#  'original': 414,
#  'other': 415,
#  'ought': 416,
#  'out': 417,
#  'outcome': 418,
#  'outdone': 419,
#  'over': 420,
#  'own': 421,
#  'panicked': 422,
#  'paranoid': 423,
#  'particularly': 424,
#  'party': 425,
#  'pass': 426,
#  'patients': 427,
#  'paul': 428,
#  'payroll': 429,
#  'people': 430,
#  'personal': 431,
#  'pic': 432,
#  'picked': 433,
#  'picking': 434,
#  'pieces': 435,
#  'pinterest': 436,
#  'place': 437,
#  'plan': 438,
#  'playing': 439,
#  'pocket': 440,
#  'political': 441,
#  'politics': 442,
#  'poses': 443,
#  'positive': 444,
#  'possible': 445,
#  'postured': 446,
#  'power': 447,
#  'practically': 448,
#  'preemptive': 449,
#  'preemptively': 450,
#  'president': 451,
#  'presidential': 452,
#  'pretend': 453,
#  'pretending': 454,
#  'previously': 455,
#  'principled': 456,
#  'principles': 457,
#  'print': 458,
#  'pro': 459,
#  'procedural': 460,
#  'procedure': 461,
#  'prominent': 462,
#  'promising': 463,
#  'protecting': 464,
#  'proved': 465,
#  'public': 466,
#  'published': 467,
#  'pure': 468,
#  'push': 469,
#  'putin': 470,
#  'question': 471,
#  'questions': 472,
#  'quickly': 473,
#  'radical': 474,
#  'rally': 475,
#  'ranks': 476,
#  'rating': 477,
#  're': 478,
#  'react': 479,
#  'realdonaldtrump': 480,
#  'reality': 481,
#  'really': 482,
#  'reason': 483,
#  'recalls': 484,
#  'recover': 485,
#  'reddit': 486,
#  'refused': 487,
#  'reid': 488,
#  'relevance': 489,
#  'relief': 490,
#  'remembered': 491,
#  'remind': 492,
#  'replaced': 493,
#  'republican': 494,
#  'republicans': 495,
#  'resignation': 496,
#  'respected': 497,
#  'respond': 498,
#  'results': 499,
#  'retired': 500,
#  'reveal': 501,
#  'revelation': 502,
#  'reversed': 503,
#  'review': 504,
#  'ride': 505,
#  'rigged': 506,
#  'right': 507,
#  'ringing': 508,
#  'risk': 509,
#  'rodham': 510,
#  'role': 511,
#  'running': 512,
#  'ryan': 513,
#  's': 514,
#  'same': 515,
#  'savage': 516,
#  'says': 517,
#  'scandal': 518,
#  'scandals': 519,
#  'scene': 520,
#  'screwed': 521,
#  'security': 522,
#  'seemed': 523,
#  'senator': 524,
#  'senior': 525,
#  'sent': 526,
#  'server': 527,
#  'setup': 528,
#  'sexism': 529,
#  'sexual': 530,
#  'she': 531,
#  'shillman': 532,
#  'short': 533,
#  'shove': 534,
#  'shown': 535,
#  'shrugged': 536,
#  'sigh': 537,
#  'slightest': 538,
#  'smart': 539,
#  'smell': 540,
#  'smoke': 541,
#  'sniveling': 542,
#  'so': 543,
#  'space': 544,
#  'speaker': 545,
#  'speakerryan': 546,
#  'speaks': 547,
#  'spectrum': 548,
#  'spinelessness': 549,
#  'spinmeisters': 550,
#  'spouting': 551,
#  'stage': 552,
#  'staggering': 553,
#  'stand': 554,
#  'start': 555,
#  'statement': 556,
#  'states': 557,
#  'stay': 558,
#  'step': 559,
#  'still': 560,
#  'stored': 561,
#  'stories': 562,
#  'strange': 563,
#  'strategy': 564,
#  'stretch': 565,
#  'struggle': 566,
#  'stumbleupon': 567,
#  'substance': 568,
#  'such': 569,
#  'sudden': 570,
#  'suddenly': 571,
#  'supporting': 572,
#  'surprising': 573,
#  'surreal': 574,
#  'survival': 575,
#  't': 576,
#  'table': 577,
#  'tak': 578,
#  'taking': 579,
#  'talked': 580,
#  'tape': 581,
#  'targeting': 582,
#  'television': 583,
#  'tells': 584,
#  'tenth': 585,
#  'than': 586,
#  'that': 587,
#  'the': 588,
#  'their': 589,
#  'them': 590,
#  'then': 591,
#  'there': 592,
#  'they': 593,
#  'thing': 594,
#  'this': 595,
#  'those': 596,
#  'thought': 597,
#  'threat': 598,
#  'through': 599,
#  'throughout': 600,
#  'thrown': 601,
#  'tied': 602,
#  'time': 603,
#  'times': 604,
#  'to': 605,
#  'today': 606,
#  'too': 607,
#  'train': 608,
#  'trapped': 609,
#  'trash': 610,
#  'truly': 611,
#  'trump': 612,
#  'truths': 613,
#  'try': 614,
#  'trying': 615,
#  'tumblr': 616,
#  'turned': 617,
#  'twitter': 618,
#  'two': 619,
#  'ugly': 620,
#  'unapologetic': 621,
#  'uncomfortable': 622,
#  'under': 623,
#  'underway': 624,
#  'unfavorable': 625,
#  'unite': 626,
#  'united': 627,
#  'unprecedented': 628,
#  'unscathed': 629,
#  'until': 630,
#  'up': 631,
#  'us': 632,
#  'used': 633,
#  'usual': 634,
#  'utter': 635,
#  'value': 636,
#  'vast': 637,
#  'very': 638,
#  'victory': 639,
#  'violating': 640,
#  'violation': 641,
#  'vladimir': 642,
#  'volumes': 643,
#  'vote': 644,
#  'voted': 645,
#  'vytt49yvoe': 646,
#  'wake': 647,
#  'waking': 648,
#  'want': 649,
#  'wants': 650,
#  'war': 651,
#  'warned': 652,
#  'warning': 653,
#  'was': 654,
#  'watching': 655,
#  'way': 656,
#  'wcvscg4a5i': 657,
#  'weathered': 658,
#  'weeks': 659,
#  'weiner': 660,
#  'well': 661,
#  'went': 662,
#  'were': 663,
#  'what': 664,
#  'whatever': 665,
#  'when': 666,
#  'where': 667,
#  'whether': 668,
#  'which': 669,
#  'while': 670,
#  'who': 671,
#  'whole': 672,
#  'whose': 673,
#  'why': 674,
#  'wikipedia': 675,
#  'will': 676,
#  'wing': 677,
#  'wiretaps': 678,
#  'wisconsin': 679,
#  'with': 680,
#  'within': 681,
#  'without': 682,
#  'women': 683,
#  'word': 684,
#  'world': 685,
#  'would': 686,
#  'wouldn': 687,
#  'wound': 688,
#  'wreck': 689,
#  'wreckage': 690,
#  'writer': 691,
#  'wrong': 692,
#  'years': 693,
#  'york': 694,
#  'you': 695,
#  'your': 696,
#  'zero': 697}

# %%
n_words=10
inp_words=[]
nxt_words=[]

# %%
for i in range(len(tokens)-n_words):
    inp_words.append(tokens[i:i+n_words])
    nxt_words.append(tokens[i+n_words])

# %%
inp_words
# Out:
# [['daniel',
#   'greenfield',
#   'a',
#   'shillman',
#   'journalism',
#   'fellow',
#   'at',
#   'the',
#   'freedom',
#   'center'],
#  ['greenfield',
#   'a',
#   'shillman',
#   'journalism',
#   'fellow',
#   'at',
#   'the',
#   'freedom',
#   'center',
#   'is'],
#  ['a',
#   'shillman',
#   'journalism',
#   'fellow',
#   'at',
#   'the',
#   'freedom',
#   'center',
#   'is',
#   'a'],
#  ['shillman',
#   'journalism',
#   'fellow',
#   'at',
#   'the',
#   'freedom',
#   'center',
#   'is',
#   'a',
#   'new'],
#  ['journalism',
#   'fellow',
#   'at',
#   'the',
#   'freedom',
#   'center',
#   'is',
#   'a',
#   'new',
#   'york'],
#  ['fellow',
#   'at',
#   'the',
#   'freedom',
#   'center',
#   'is',
#   'a',
#   'new',
#   'york',
#   'writer'],
#  ['at',
#   'the',
#   'freedom',
#   'center',
#   'is',
#   'a',
#   'new',
#   'york',
#   'writer',
#   'focusing'],
#  ['the',
#   'freedom',
#   'center',
#   'is',
#   'a',
#   'new',
#   'york',
#   'writer',
#   'focusing',
#   'on'],
#  ['freedom',
#   'center',
#   'is',
#   'a',
#   'new',
#   'york',
#   'writer',
#   'focusing',
#   'on',
#   'radical'],
#  ['center',
#   'is',
#   'a',
#   'new',
#   'york',
#   'writer',
#   'focusing',
#   'on',
#   'radical',
#   'islam'],
#  ['is',
#   'a',
#   'new',
#   'york',
#   'writer',
#   'focusing',
#   'on',
#   'radical',
#   'islam',
#   'in'],
#  ['a',
#   'new',
#   'york',
#   'writer',
#   'focusing',
#   'on',
#   'radical',
#   'islam',
#   'in',
#   'the'],
#  ['new',
#   'york',
#   'writer',
#   'focusing',
#   'on',
#   'radical',
#   'islam',
#   'in',
#   'the',
#   'final'],
#  ['york',
#   'writer',
#   'focusing',
#   'on',
#   'radical',
#   'islam',
#   'in',
#   'the',
#   'final',
#   'stretch'],
#  ['writer',
#   'focusing',
#   'on',
#   'radical',
#   'islam',
#   'in',
#   'the',
#   'final',
#   'stretch',
#   'of'],
#  ['focusing',
#   'on',
#   'radical',
#   'islam',
#   'in',
#   'the',
#   'final',
#   'stretch',
#   'of',
#   'the'],
#  ['on',
#   'radical',
#   'islam',
#   'in',
#   'the',
#   'final',
#   'stretch',
#   'of',
#   'the',
#   'election'],
#  ['radical',
#   'islam',
#   'in',
#   'the',
#   'final',
#   'stretch',
#   'of',
#   'the',
#   'election',
#   'hillary'],
#  ['islam',
#   'in',
#   'the',
#   'final',
#   'stretch',
#   'of',
#   'the',
#   'election',
#   'hillary',
#   'rodham'],
#  ['in',
#   'the',
#   'final',
#   'stretch',
#   'of',
#   'the',
#   'election',
#   'hillary',
#   'rodham',
#   'clinton'],
#  ['the',
#   'final',
#   'stretch',
#   'of',
#   'the',
#   'election',
#   'hillary',
#   'rodham',
#   'clinton',
#   'has'],
#  ['final',
#   'stretch',
#   'of',
#   'the',
#   'election',
#   'hillary',
#   'rodham',
#   'clinton',
#   'has',
#   'gone'],
#  ['stretch',
#   'of',
#   'the',
#   'election',
#   'hillary',
#   'rodham',
#   'clinton',
#   'has',
#   'gone',
#   'to'],
#  ['of',
#   'the',
#   'election',
#   'hillary',
#   'rodham',
#   'clinton',
#   'has',
#   'gone',
#   'to',
#   'war'],
#  ['the',
#   'election',
#   'hillary',
#   'rodham',
#   'clinton',
#   'has',
#   'gone',
#   'to',
#   'war',
#   'with'],
#  ['election',
#   'hillary',
#   'rodham',
#   'clinton',
#   'has',
#   'gone',
#   'to',
#   'war',
#   'with',
#   'the'],
#  ['hillary',
#   'rodham',
#   'clinton',
#   'has',
#   'gone',
#   'to',
#   'war',
#   'with',
#   'the',
#   'fbi'],
#  ['rodham',
#   'clinton',
#   'has',
#   'gone',
#   'to',
#   'war',
#   'with',
#   'the',
#   'fbi',
#   'the'],
#  ['clinton', 'has', 'gone', 'to', 'war', 'with', 'the', 'fbi', 'the', 'word'],
#  ['has',
#   'gone',
#   'to',
#   'war',
#   'with',
#   'the',
#   'fbi',
#   'the',
#   'word',
#   'unprecedented'],
#  ['gone',
#   'to',
#   'war',
#   'with',
#   'the',
#   'fbi',
#   'the',
#   'word',
#   'unprecedented',
#   'has'],
#  ['to',
#   'war',
#   'with',
#   'the',
#   'fbi',
#   'the',
#   'word',
#   'unprecedented',
#   'has',
#   'been'],
#  ['war',
#   'with',
#   'the',
#   'fbi',
#   'the',
#   'word',
#   'unprecedented',
#   'has',
#   'been',
#   'thrown'],
#  ['with',
#   'the',
#   'fbi',
#   'the',
#   'word',
#   'unprecedented',
#   'has',
#   'been',
#   'thrown',
#   'around'],
#  ['the',
#   'fbi',
#   'the',
#   'word',
#   'unprecedented',
#   'has',
#   'been',
#   'thrown',
#   'around',
#   'so'],
#  ['fbi',
#   'the',
#   'word',
#   'unprecedented',
#   'has',
#   'been',
#   'thrown',
#   'around',
#   'so',
#   'often'],
#  ['the',
#   'word',
#   'unprecedented',
#   'has',
#   'been',
#   'thrown',
#   'around',
#   'so',
#   'often',
#   'this'],
#  ['word',
#   'unprecedented',
#   'has',
#   'been',
#   'thrown',
#   'around',
#   'so',
#   'often',
#   'this',
#   'election'],
#  ['unprecedented',
#   'has',
#   'been',
#   'thrown',
#   'around',
#   'so',
#   'often',
#   'this',
#   'election',
#   'that'],
#  ['has',
#   'been',
#   'thrown',
#   'around',
#   'so',
#   'often',
#   'this',
#   'election',
#   'that',
#   'it'],
#  ['been',
#   'thrown',
#   'around',
#   'so',
#   'often',
#   'this',
#   'election',
#   'that',
#   'it',
#   'ought'],
#  ['thrown',
#   'around',
#   'so',
#   'often',
#   'this',
#   'election',
#   'that',
#   'it',
#   'ought',
#   'to'],
#  ['around',
#   'so',
#   'often',
#   'this',
#   'election',
#   'that',
#   'it',
#   'ought',
#   'to',
#   'be'],
#  ['so',
#   'often',
#   'this',
#   'election',
#   'that',
#   'it',
#   'ought',
#   'to',
#   'be',
#   'retired'],
#  ['often',
#   'this',
#   'election',
#   'that',
#   'it',
#   'ought',
#   'to',
#   'be',
#   'retired',
#   'but'],
#  ['this',
#   'election',
#   'that',
#   'it',
#   'ought',
#   'to',
#   'be',
#   'retired',
#   'but',
#   'it'],
#  ['election', 'that', 'it', 'ought', 'to', 'be', 'retired', 'but', 'it', 's'],
#  ['that', 'it', 'ought', 'to', 'be', 'retired', 'but', 'it', 's', 'still'],
#  ['it',
#   'ought',
#   'to',
#   'be',
#   'retired',
#   'but',
#   'it',
#   's',
#   'still',
#   'unprecedented'],
#  ['ought',
#   'to',
#   'be',
#   'retired',
#   'but',
#   'it',
#   's',
#   'still',
#   'unprecedented',
#   'for'],
#  ['to',
#   'be',
#   'retired',
#   'but',
#   'it',
#   's',
#   'still',
#   'unprecedented',
#   'for',
#   'the'],
#  ['be',
#   'retired',
#   'but',
#   'it',
#   's',
#   'still',
#   'unprecedented',
#   'for',
#   'the',
#   'nominee'],
#  ['retired',
#   'but',
#   'it',
#   's',
#   'still',
#   'unprecedented',
#   'for',
#   'the',
#   'nominee',
#   'of'],
#  ['but',
#   'it',
#   's',
#   'still',
#   'unprecedented',
#   'for',
#   'the',
#   'nominee',
#   'of',
#   'a'],
#  ['it',
#   's',
#   'still',
#   'unprecedented',
#   'for',
#   'the',
#   'nominee',
#   'of',
#   'a',
#   'major'],
#  ['s',
#   'still',
#   'unprecedented',
#   'for',
#   'the',
#   'nominee',
#   'of',
#   'a',
#   'major',
#   'political'],
#  ['still',
#   'unprecedented',
#   'for',
#   'the',
#   'nominee',
#   'of',
#   'a',
#   'major',
#   'political',
#   'party'],
#  ['unprecedented',
#   'for',
#   'the',
#   'nominee',
#   'of',
#   'a',
#   'major',
#   'political',
#   'party',
#   'to'],
#  ['for',
#   'the',
#   'nominee',
#   'of',
#   'a',
#   'major',
#   'political',
#   'party',
#   'to',
#   'go'],
#  ['the',
#   'nominee',
#   'of',
#   'a',
#   'major',
#   'political',
#   'party',
#   'to',
#   'go',
#   'war'],
#  ['nominee',
#   'of',
#   'a',
#   'major',
#   'political',
#   'party',
#   'to',
#   'go',
#   'war',
#   'with'],
#  ['of', 'a', 'major', 'political', 'party', 'to', 'go', 'war', 'with', 'the'],
#  ['a', 'major', 'political', 'party', 'to', 'go', 'war', 'with', 'the', 'fbi'],
#  ['major',
#   'political',
#   'party',
#   'to',
#   'go',
#   'war',
#   'with',
#   'the',
#   'fbi',
#   'but'],
#  ['political',
#   'party',
#   'to',
#   'go',
#   'war',
#   'with',
#   'the',
#   'fbi',
#   'but',
#   'that'],
#  ['party', 'to', 'go', 'war', 'with', 'the', 'fbi', 'but', 'that', 's'],
#  ['to', 'go', 'war', 'with', 'the', 'fbi', 'but', 'that', 's', 'exactly'],
#  ['go', 'war', 'with', 'the', 'fbi', 'but', 'that', 's', 'exactly', 'what'],
#  ['war',
#   'with',
#   'the',
#   'fbi',
#   'but',
#   'that',
#   's',
#   'exactly',
#   'what',
#   'hillary'],
#  ['with',
#   'the',
#   'fbi',
#   'but',
#   'that',
#   's',
#   'exactly',
#   'what',
#   'hillary',
#   'and'],
#  ['the',
#   'fbi',
#   'but',
#   'that',
#   's',
#   'exactly',
#   'what',
#   'hillary',
#   'and',
#   'her'],
#  ['fbi',
#   'but',
#   'that',
#   's',
#   'exactly',
#   'what',
#   'hillary',
#   'and',
#   'her',
#   'people'],
#  ['but',
#   'that',
#   's',
#   'exactly',
#   'what',
#   'hillary',
#   'and',
#   'her',
#   'people',
#   'have'],
#  ['that',
#   's',
#   'exactly',
#   'what',
#   'hillary',
#   'and',
#   'her',
#   'people',
#   'have',
#   'done'],
#  ['s',
#   'exactly',
#   'what',
#   'hillary',
#   'and',
#   'her',
#   'people',
#   'have',
#   'done',
#   'coma'],
#  ['exactly',
#   'what',
#   'hillary',
#   'and',
#   'her',
#   'people',
#   'have',
#   'done',
#   'coma',
#   'patients'],
#  ['what',
#   'hillary',
#   'and',
#   'her',
#   'people',
#   'have',
#   'done',
#   'coma',
#   'patients',
#   'just'],
#  ['hillary',
#   'and',
#   'her',
#   'people',
#   'have',
#   'done',
#   'coma',
#   'patients',
#   'just',
#   'waking'],
#  ['and',
#   'her',
#   'people',
#   'have',
#   'done',
#   'coma',
#   'patients',
#   'just',
#   'waking',
#   'up'],
#  ['her',
#   'people',
#   'have',
#   'done',
#   'coma',
#   'patients',
#   'just',
#   'waking',
#   'up',
#   'now'],
#  ['people',
#   'have',
#   'done',
#   'coma',
#   'patients',
#   'just',
#   'waking',
#   'up',
#   'now',
#   'and'],
#  ['have',
#   'done',
#   'coma',
#   'patients',
#   'just',
#   'waking',
#   'up',
#   'now',
#   'and',
#   'watching'],
#  ['done',
#   'coma',
#   'patients',
#   'just',
#   'waking',
#   'up',
#   'now',
#   'and',
#   'watching',
#   'an'],
#  ['coma',
#   'patients',
#   'just',
#   'waking',
#   'up',
#   'now',
#   'and',
#   'watching',
#   'an',
#   'hour'],
#  ['patients',
#   'just',
#   'waking',
#   'up',
#   'now',
#   'and',
#   'watching',
#   'an',
#   'hour',
#   'of'],
#  ['just', 'waking', 'up', 'now', 'and', 'watching', 'an', 'hour', 'of', 'cnn'],
#  ['waking', 'up', 'now', 'and', 'watching', 'an', 'hour', 'of', 'cnn', 'from'],
#  ['up', 'now', 'and', 'watching', 'an', 'hour', 'of', 'cnn', 'from', 'their'],
#  ['now',
#   'and',
#   'watching',
#   'an',
#   'hour',
#   'of',
#   'cnn',
#   'from',
#   'their',
#   'hospital'],
#  ['and',
#   'watching',
#   'an',
#   'hour',
#   'of',
#   'cnn',
#   'from',
#   'their',
#   'hospital',
#   'beds'],
#  ['watching',
#   'an',
#   'hour',
#   'of',
#   'cnn',
#   'from',
#   'their',
#   'hospital',
#   'beds',
#   'would'],
#  ['an',
#   'hour',
#   'of',
#   'cnn',
#   'from',
#   'their',
#   'hospital',
#   'beds',
#   'would',
#   'assume'],
#  ['hour',
#   'of',
#   'cnn',
#   'from',
#   'their',
#   'hospital',
#   'beds',
#   'would',
#   'assume',
#   'that'],
#  ['of',
#   'cnn',
#   'from',
#   'their',
#   'hospital',
#   'beds',
#   'would',
#   'assume',
#   'that',
#   'fbi'],
#  ['cnn',
#   'from',
#   'their',
#   'hospital',
#   'beds',
#   'would',
#   'assume',
#   'that',
#   'fbi',
#   'director'],
#  ['from',
#   'their',
#   'hospital',
#   'beds',
#   'would',
#   'assume',
#   'that',
#   'fbi',
#   'director',
#   'james'],
#  ['their',
#   'hospital',
#   'beds',
#   'would',
#   'assume',
#   'that',
#   'fbi',
#   'director',
#   'james',
#   'comey'],
#  ['hospital',
#   'beds',
#   'would',
#   'assume',
#   'that',
#   'fbi',
#   'director',
#   'james',
#   'comey',
#   'is'],
#  ['beds',
#   'would',
#   'assume',
#   'that',
#   'fbi',
#   'director',
#   'james',
#   'comey',
#   'is',
#   'hillary'],
#  ['would',
#   'assume',
#   'that',
#   'fbi',
#   'director',
#   'james',
#   'comey',
#   'is',
#   'hillary',
#   's'],
#  ['assume',
#   'that',
#   'fbi',
#   'director',
#   'james',
#   'comey',
#   'is',
#   'hillary',
#   's',
#   'opponent'],
#  ['that',
#   'fbi',
#   'director',
#   'james',
#   'comey',
#   'is',
#   'hillary',
#   's',
#   'opponent',
#   'in'],
#  ['fbi',
#   'director',
#   'james',
#   'comey',
#   'is',
#   'hillary',
#   's',
#   'opponent',
#   'in',
#   'this'],
#  ['director',
#   'james',
#   'comey',
#   'is',
#   'hillary',
#   's',
#   'opponent',
#   'in',
#   'this',
#   'election'],
#  ['james',
#   'comey',
#   'is',
#   'hillary',
#   's',
#   'opponent',
#   'in',
#   'this',
#   'election',
#   'the'],
#  ['comey',
#   'is',
#   'hillary',
#   's',
#   'opponent',
#   'in',
#   'this',
#   'election',
#   'the',
#   'fbi'],
#  ['is',
#   'hillary',
#   's',
#   'opponent',
#   'in',
#   'this',
#   'election',
#   'the',
#   'fbi',
#   'is'],
#  ['hillary',
#   's',
#   'opponent',
#   'in',
#   'this',
#   'election',
#   'the',
#   'fbi',
#   'is',
#   'under'],
#  ['s',
#   'opponent',
#   'in',
#   'this',
#   'election',
#   'the',
#   'fbi',
#   'is',
#   'under',
#   'attack'],
#  ['opponent',
#   'in',
#   'this',
#   'election',
#   'the',
#   'fbi',
#   'is',
#   'under',
#   'attack',
#   'by'],
#  ['in',
#   'this',
#   'election',
#   'the',
#   'fbi',
#   'is',
#   'under',
#   'attack',
#   'by',
#   'everyone'],
#  ['this',
#   'election',
#   'the',
#   'fbi',
#   'is',
#   'under',
#   'attack',
#   'by',
#   'everyone',
#   'from'],
#  ['election',
#   'the',
#   'fbi',
#   'is',
#   'under',
#   'attack',
#   'by',
#   'everyone',
#   'from',
#   'obama'],
#  ['the',
#   'fbi',
#   'is',
#   'under',
#   'attack',
#   'by',
#   'everyone',
#   'from',
#   'obama',
#   'to'],
#  ['fbi',
#   'is',
#   'under',
#   'attack',
#   'by',
#   'everyone',
#   'from',
#   'obama',
#   'to',
#   'cnn'],
#  ['is',
#   'under',
#   'attack',
#   'by',
#   'everyone',
#   'from',
#   'obama',
#   'to',
#   'cnn',
#   'hillary'],
#  ['under',
#   'attack',
#   'by',
#   'everyone',
#   'from',
#   'obama',
#   'to',
#   'cnn',
#   'hillary',
#   's'],
#  ['attack',
#   'by',
#   'everyone',
#   'from',
#   'obama',
#   'to',
#   'cnn',
#   'hillary',
#   's',
#   'people'],
#  ['by',
#   'everyone',
#   'from',
#   'obama',
#   'to',
#   'cnn',
#   'hillary',
#   's',
#   'people',
#   'have'],
#  ['everyone',
#   'from',
#   'obama',
#   'to',
#   'cnn',
#   'hillary',
#   's',
#   'people',
#   'have',
#   'circulated'],
#  ['from',
#   'obama',
#   'to',
#   'cnn',
#   'hillary',
#   's',
#   'people',
#   'have',
#   'circulated',
#   'a'],
#  ['obama',
#   'to',
#   'cnn',
#   'hillary',
#   's',
#   'people',
#   'have',
#   'circulated',
#   'a',
#   'letter'],
#  ['to',
#   'cnn',
#   'hillary',
#   's',
#   'people',
#   'have',
#   'circulated',
#   'a',
#   'letter',
#   'attacking'],
#  ['cnn',
#   'hillary',
#   's',
#   'people',
#   'have',
#   'circulated',
#   'a',
#   'letter',
#   'attacking',
#   'comey'],
#  ['hillary',
#   's',
#   'people',
#   'have',
#   'circulated',
#   'a',
#   'letter',
#   'attacking',
#   'comey',
#   'there'],
#  ['s',
#   'people',
#   'have',
#   'circulated',
#   'a',
#   'letter',
#   'attacking',
#   'comey',
#   'there',
#   'are'],
#  ['people',
#   'have',
#   'circulated',
#   'a',
#   'letter',
#   'attacking',
#   'comey',
#   'there',
#   'are',
#   'currently'],
#  ['have',
#   'circulated',
#   'a',
#   'letter',
#   'attacking',
#   'comey',
#   'there',
#   'are',
#   'currently',
#   'more'],
#  ['circulated',
#   'a',
#   'letter',
#   'attacking',
#   'comey',
#   'there',
#   'are',
#   'currently',
#   'more',
#   'media'],
#  ['a',
#   'letter',
#   'attacking',
#   'comey',
#   'there',
#   'are',
#   'currently',
#   'more',
#   'media',
#   'hit'],
#  ['letter',
#   'attacking',
#   'comey',
#   'there',
#   'are',
#   'currently',
#   'more',
#   'media',
#   'hit',
#   'pieces'],
#  ['attacking',
#   'comey',
#   'there',
#   'are',
#   'currently',
#   'more',
#   'media',
#   'hit',
#   'pieces',
#   'lambasting'],
#  ['comey',
#   'there',
#   'are',
#   'currently',
#   'more',
#   'media',
#   'hit',
#   'pieces',
#   'lambasting',
#   'him'],
#  ['there',
#   'are',
#   'currently',
#   'more',
#   'media',
#   'hit',
#   'pieces',
#   'lambasting',
#   'him',
#   'than'],
#  ['are',
#   'currently',
#   'more',
#   'media',
#   'hit',
#   'pieces',
#   'lambasting',
#   'him',
#   'than',
#   'targeting'],
#  ['currently',
#   'more',
#   'media',
#   'hit',
#   'pieces',
#   'lambasting',
#   'him',
#   'than',
#   'targeting',
#   'trump'],
#  ['more',
#   'media',
#   'hit',
#   'pieces',
#   'lambasting',
#   'him',
#   'than',
#   'targeting',
#   'trump',
#   'it'],
#  ['media',
#   'hit',
#   'pieces',
#   'lambasting',
#   'him',
#   'than',
#   'targeting',
#   'trump',
#   'it',
#   'wouldn'],
#  ['hit',
#   'pieces',
#   'lambasting',
#   'him',
#   'than',
#   'targeting',
#   'trump',
#   'it',
#   'wouldn',
#   't'],
#  ['pieces',
#   'lambasting',
#   'him',
#   'than',
#   'targeting',
#   'trump',
#   'it',
#   'wouldn',
#   't',
#   'be'],
#  ['lambasting',
#   'him',
#   'than',
#   'targeting',
#   'trump',
#   'it',
#   'wouldn',
#   't',
#   'be',
#   'too'],
#  ['him',
#   'than',
#   'targeting',
#   'trump',
#   'it',
#   'wouldn',
#   't',
#   'be',
#   'too',
#   'surprising'],
#  ['than',
#   'targeting',
#   'trump',
#   'it',
#   'wouldn',
#   't',
#   'be',
#   'too',
#   'surprising',
#   'if'],
#  ['targeting',
#   'trump',
#   'it',
#   'wouldn',
#   't',
#   'be',
#   'too',
#   'surprising',
#   'if',
#   'the'],
#  ['trump',
#   'it',
#   'wouldn',
#   't',
#   'be',
#   'too',
#   'surprising',
#   'if',
#   'the',
#   'clintons'],
#  ['it',
#   'wouldn',
#   't',
#   'be',
#   'too',
#   'surprising',
#   'if',
#   'the',
#   'clintons',
#   'or'],
#  ['wouldn',
#   't',
#   'be',
#   'too',
#   'surprising',
#   'if',
#   'the',
#   'clintons',
#   'or',
#   'their'],
#  ['t',
#   'be',
#   'too',
#   'surprising',
#   'if',
#   'the',
#   'clintons',
#   'or',
#   'their',
#   'allies'],
#  ['be',
#   'too',
#   'surprising',
#   'if',
#   'the',
#   'clintons',
#   'or',
#   'their',
#   'allies',
#   'were'],
#  ['too',
#   'surprising',
#   'if',
#   'the',
#   'clintons',
#   'or',
#   'their',
#   'allies',
#   'were',
#   'to'],
#  ['surprising',
#   'if',
#   'the',
#   'clintons',
#   'or',
#   'their',
#   'allies',
#   'were',
#   'to',
#   'start'],
#  ['if',
#   'the',
#   'clintons',
#   'or',
#   'their',
#   'allies',
#   'were',
#   'to',
#   'start',
#   'running'],
#  ['the',
#   'clintons',
#   'or',
#   'their',
#   'allies',
#   'were',
#   'to',
#   'start',
#   'running',
#   'attack'],
#  ['clintons',
#   'or',
#   'their',
#   'allies',
#   'were',
#   'to',
#   'start',
#   'running',
#   'attack',
#   'ads'],
#  ['or',
#   'their',
#   'allies',
#   'were',
#   'to',
#   'start',
#   'running',
#   'attack',
#   'ads',
#   'against'],
#  ['their',
#   'allies',
#   'were',
#   'to',
#   'start',
#   'running',
#   'attack',
#   'ads',
#   'against',
#   'the'],
#  ['allies',
#   'were',
#   'to',
#   'start',
#   'running',
#   'attack',
#   'ads',
#   'against',
#   'the',
#   'fbi'],
#  ['were',
#   'to',
#   'start',
#   'running',
#   'attack',
#   'ads',
#   'against',
#   'the',
#   'fbi',
#   'the'],
#  ['to',
#   'start',
#   'running',
#   'attack',
#   'ads',
#   'against',
#   'the',
#   'fbi',
#   'the',
#   'fbi'],
#  ['start',
#   'running',
#   'attack',
#   'ads',
#   'against',
#   'the',
#   'fbi',
#   'the',
#   'fbi',
#   's'],
#  ['running',
#   'attack',
#   'ads',
#   'against',
#   'the',
#   'fbi',
#   'the',
#   'fbi',
#   's',
#   'leadership'],
#  ['attack',
#   'ads',
#   'against',
#   'the',
#   'fbi',
#   'the',
#   'fbi',
#   's',
#   'leadership',
#   'is'],
#  ['ads',
#   'against',
#   'the',
#   'fbi',
#   'the',
#   'fbi',
#   's',
#   'leadership',
#   'is',
#   'being'],
#  ['against',
#   'the',
#   'fbi',
#   'the',
#   'fbi',
#   's',
#   'leadership',
#   'is',
#   'being',
#   'warned'],
#  ['the',
#   'fbi',
#   'the',
#   'fbi',
#   's',
#   'leadership',
#   'is',
#   'being',
#   'warned',
#   'that'],
#  ['fbi',
#   'the',
#   'fbi',
#   's',
#   'leadership',
#   'is',
#   'being',
#   'warned',
#   'that',
#   'the'],
#  ['the',
#   'fbi',
#   's',
#   'leadership',
#   'is',
#   'being',
#   'warned',
#   'that',
#   'the',
#   'entire'],
#  ['fbi',
#   's',
#   'leadership',
#   'is',
#   'being',
#   'warned',
#   'that',
#   'the',
#   'entire',
#   'left'],
#  ['s',
#   'leadership',
#   'is',
#   'being',
#   'warned',
#   'that',
#   'the',
#   'entire',
#   'left',
#   'wing'],
#  ['leadership',
#   'is',
#   'being',
#   'warned',
#   'that',
#   'the',
#   'entire',
#   'left',
#   'wing',
#   'establishment'],
#  ['is',
#   'being',
#   'warned',
#   'that',
#   'the',
#   'entire',
#   'left',
#   'wing',
#   'establishment',
#   'will'],
#  ['being',
#   'warned',
#   'that',
#   'the',
#   'entire',
#   'left',
#   'wing',
#   'establishment',
#   'will',
#   'form'],
#  ['warned',
#   'that',
#   'the',
#   'entire',
#   'left',
#   'wing',
#   'establishment',
#   'will',
#   'form',
#   'a'],
#  ['that',
#   'the',
#   'entire',
#   'left',
#   'wing',
#   'establishment',
#   'will',
#   'form',
#   'a',
#   'lynch'],
#  ['the',
#   'entire',
#   'left',
#   'wing',
#   'establishment',
#   'will',
#   'form',
#   'a',
#   'lynch',
#   'mob'],
#  ['entire',
#   'left',
#   'wing',
#   'establishment',
#   'will',
#   'form',
#   'a',
#   'lynch',
#   'mob',
#   'if'],
#  ['left',
#   'wing',
#   'establishment',
#   'will',
#   'form',
#   'a',
#   'lynch',
#   'mob',
#   'if',
#   'they'],
#  ['wing',
#   'establishment',
#   'will',
#   'form',
#   'a',
#   'lynch',
#   'mob',
#   'if',
#   'they',
#   'continue'],
#  ['establishment',
#   'will',
#   'form',
#   'a',
#   'lynch',
#   'mob',
#   'if',
#   'they',
#   'continue',
#   'going'],
#  ['will',
#   'form',
#   'a',
#   'lynch',
#   'mob',
#   'if',
#   'they',
#   'continue',
#   'going',
#   'after'],
#  ['form',
#   'a',
#   'lynch',
#   'mob',
#   'if',
#   'they',
#   'continue',
#   'going',
#   'after',
#   'hillary'],
#  ['a',
#   'lynch',
#   'mob',
#   'if',
#   'they',
#   'continue',
#   'going',
#   'after',
#   'hillary',
#   'and'],
#  ['lynch',
#   'mob',
#   'if',
#   'they',
#   'continue',
#   'going',
#   'after',
#   'hillary',
#   'and',
#   'the'],
#  ['mob',
#   'if',
#   'they',
#   'continue',
#   'going',
#   'after',
#   'hillary',
#   'and',
#   'the',
#   'fbi'],
#  ['if',
#   'they',
#   'continue',
#   'going',
#   'after',
#   'hillary',
#   'and',
#   'the',
#   'fbi',
#   's'],
#  ['they',
#   'continue',
#   'going',
#   'after',
#   'hillary',
#   'and',
#   'the',
#   'fbi',
#   's',
#   'credibility'],
#  ['continue',
#   'going',
#   'after',
#   'hillary',
#   'and',
#   'the',
#   'fbi',
#   's',
#   'credibility',
#   'is'],
#  ['going',
#   'after',
#   'hillary',
#   'and',
#   'the',
#   'fbi',
#   's',
#   'credibility',
#   'is',
#   'being'],
#  ['after',
#   'hillary',
#   'and',
#   'the',
#   'fbi',
#   's',
#   'credibility',
#   'is',
#   'being',
#   'attacked'],
#  ['hillary',
#   'and',
#   'the',
#   'fbi',
#   's',
#   'credibility',
#   'is',
#   'being',
#   'attacked',
#   'by'],
#  ['and',
#   'the',
#   'fbi',
#   's',
#   'credibility',
#   'is',
#   'being',
#   'attacked',
#   'by',
#   'the'],
#  ['the',
#   'fbi',
#   's',
#   'credibility',
#   'is',
#   'being',
#   'attacked',
#   'by',
#   'the',
#   'media'],
#  ['fbi',
#   's',
#   'credibility',
#   'is',
#   'being',
#   'attacked',
#   'by',
#   'the',
#   'media',
#   'and'],
#  ['s',
#   'credibility',
#   'is',
#   'being',
#   'attacked',
#   'by',
#   'the',
#   'media',
#   'and',
#   'the'],
#  ['credibility',
#   'is',
#   'being',
#   'attacked',
#   'by',
#   'the',
#   'media',
#   'and',
#   'the',
#   'democrats'],
#  ['is',
#   'being',
#   'attacked',
#   'by',
#   'the',
#   'media',
#   'and',
#   'the',
#   'democrats',
#   'to'],
#  ['being',
#   'attacked',
#   'by',
#   'the',
#   'media',
#   'and',
#   'the',
#   'democrats',
#   'to',
#   'preemptively'],
#  ['attacked',
#   'by',
#   'the',
#   'media',
#   'and',
#   'the',
#   'democrats',
#   'to',
#   'preemptively',
#   'head'],
#  ['by',
#   'the',
#   'media',
#   'and',
#   'the',
#   'democrats',
#   'to',
#   'preemptively',
#   'head',
#   'off'],
#  ['the',
#   'media',
#   'and',
#   'the',
#   'democrats',
#   'to',
#   'preemptively',
#   'head',
#   'off',
#   'the'],
#  ['media',
#   'and',
#   'the',
#   'democrats',
#   'to',
#   'preemptively',
#   'head',
#   'off',
#   'the',
#   'results'],
#  ['and',
#   'the',
#   'democrats',
#   'to',
#   'preemptively',
#   'head',
#   'off',
#   'the',
#   'results',
#   'of'],
#  ['the',
#   'democrats',
#   'to',
#   'preemptively',
#   'head',
#   'off',
#   'the',
#   'results',
#   'of',
#   'the'],
#  ['democrats',
#   'to',
#   'preemptively',
#   'head',
#   'off',
#   'the',
#   'results',
#   'of',
#   'the',
#   'investigation'],
#  ['to',
#   'preemptively',
#   'head',
#   'off',
#   'the',
#   'results',
#   'of',
#   'the',
#   'investigation',
#   'of'],
#  ['preemptively',
#   'head',
#   'off',
#   'the',
#   'results',
#   'of',
#   'the',
#   'investigation',
#   'of',
#   'the'],
#  ['head',
#   'off',
#   'the',
#   'results',
#   'of',
#   'the',
#   'investigation',
#   'of',
#   'the',
#   'clinton'],
#  ['off',
#   'the',
#   'results',
#   'of',
#   'the',
#   'investigation',
#   'of',
#   'the',
#   'clinton',
#   'foundation'],
#  ['the',
#   'results',
#   'of',
#   'the',
#   'investigation',
#   'of',
#   'the',
#   'clinton',
#   'foundation',
#   'and'],
#  ['results',
#   'of',
#   'the',
#   'investigation',
#   'of',
#   'the',
#   'clinton',
#   'foundation',
#   'and',
#   'hillary'],
#  ['of',
#   'the',
#   'investigation',
#   'of',
#   'the',
#   'clinton',
#   'foundation',
#   'and',
#   'hillary',
#   'clinton'],
#  ['the',
#   'investigation',
#   'of',
#   'the',
#   'clinton',
#   'foundation',
#   'and',
#   'hillary',
#   'clinton',
#   'the'],
#  ['investigation',
#   'of',
#   'the',
#   'clinton',
#   'foundation',
#   'and',
#   'hillary',
#   'clinton',
#   'the',
#   'covert'],
#  ['of',
#   'the',
#   'clinton',
#   'foundation',
#   'and',
#   'hillary',
#   'clinton',
#   'the',
#   'covert',
#   'struggle'],
#  ['the',
#   'clinton',
#   'foundation',
#   'and',
#   'hillary',
#   'clinton',
#   'the',
#   'covert',
#   'struggle',
#   'between'],
#  ['clinton',
#   'foundation',
#   'and',
#   'hillary',
#   'clinton',
#   'the',
#   'covert',
#   'struggle',
#   'between',
#   'fbi'],
#  ['foundation',
#   'and',
#   'hillary',
#   'clinton',
#   'the',
#   'covert',
#   'struggle',
#   'between',
#   'fbi',
#   'agents'],
#  ['and',
#   'hillary',
#   'clinton',
#   'the',
#   'covert',
#   'struggle',
#   'between',
#   'fbi',
#   'agents',
#   'and'],
#  ['hillary',
#   'clinton',
#   'the',
#   'covert',
#   'struggle',
#   'between',
#   'fbi',
#   'agents',
#   'and',
#   'obama'],
#  ['clinton',
#   'the',
#   'covert',
#   'struggle',
#   'between',
#   'fbi',
#   'agents',
#   'and',
#   'obama',
#   's'],
#  ['the',
#   'covert',
#   'struggle',
#   'between',
#   'fbi',
#   'agents',
#   'and',
#   'obama',
#   's',
#   'doj'],
#  ['covert',
#   'struggle',
#   'between',
#   'fbi',
#   'agents',
#   'and',
#   'obama',
#   's',
#   'doj',
#   'people'],
#  ['struggle',
#   'between',
#   'fbi',
#   'agents',
#   'and',
#   'obama',
#   's',
#   'doj',
#   'people',
#   'has'],
#  ['between',
#   'fbi',
#   'agents',
#   'and',
#   'obama',
#   's',
#   'doj',
#   'people',
#   'has',
#   'gone'],
#  ['fbi',
#   'agents',
#   'and',
#   'obama',
#   's',
#   'doj',
#   'people',
#   'has',
#   'gone',
#   'explosively'],
#  ['agents',
#   'and',
#   'obama',
#   's',
#   'doj',
#   'people',
#   'has',
#   'gone',
#   'explosively',
#   'public'],
#  ['and',
#   'obama',
#   's',
#   'doj',
#   'people',
#   'has',
#   'gone',
#   'explosively',
#   'public',
#   'the'],
#  ['obama',
#   's',
#   'doj',
#   'people',
#   'has',
#   'gone',
#   'explosively',
#   'public',
#   'the',
#   'new'],
#  ['s',
#   'doj',
#   'people',
#   'has',
#   'gone',
#   'explosively',
#   'public',
#   'the',
#   'new',
#   'york'],
#  ['doj',
#   'people',
#   'has',
#   'gone',
#   'explosively',
#   'public',
#   'the',
#   'new',
#   'york',
#   'times'],
#  ['people',
#   'has',
#   'gone',
#   'explosively',
#   'public',
#   'the',
#   'new',
#   'york',
#   'times',
#   'has'],
#  ['has',
#   'gone',
#   'explosively',
#   'public',
#   'the',
#   'new',
#   'york',
#   'times',
#   'has',
#   'compared'],
#  ['gone',
#   'explosively',
#   'public',
#   'the',
#   'new',
#   'york',
#   'times',
#   'has',
#   'compared',
#   'comey'],
#  ['explosively',
#   'public',
#   'the',
#   'new',
#   'york',
#   'times',
#   'has',
#   'compared',
#   'comey',
#   'to'],
#  ['public',
#   'the',
#   'new',
#   'york',
#   'times',
#   'has',
#   'compared',
#   'comey',
#   'to',
#   'j'],
#  ['the',
#   'new',
#   'york',
#   'times',
#   'has',
#   'compared',
#   'comey',
#   'to',
#   'j',
#   'edgar'],
#  ['new',
#   'york',
#   'times',
#   'has',
#   'compared',
#   'comey',
#   'to',
#   'j',
#   'edgar',
#   'hoover'],
#  ['york',
#   'times',
#   'has',
#   'compared',
#   'comey',
#   'to',
#   'j',
#   'edgar',
#   'hoover',
#   'its'],
#  ['times',
#   'has',
#   'compared',
#   'comey',
#   'to',
#   'j',
#   'edgar',
#   'hoover',
#   'its',
#   'bizarre'],
#  ['has',
#   'compared',
#   'comey',
#   'to',
#   'j',
#   'edgar',
#   'hoover',
#   'its',
#   'bizarre',
#   'headline'],
#  ['compared',
#   'comey',
#   'to',
#   'j',
#   'edgar',
#   'hoover',
#   'its',
#   'bizarre',
#   'headline',
#   'james'],
#  ['comey',
#   'to',
#   'j',
#   'edgar',
#   'hoover',
#   'its',
#   'bizarre',
#   'headline',
#   'james',
#   'comey'],
#  ['to',
#   'j',
#   'edgar',
#   'hoover',
#   'its',
#   'bizarre',
#   'headline',
#   'james',
#   'comey',
#   'role'],
#  ['j',
#   'edgar',
#   'hoover',
#   'its',
#   'bizarre',
#   'headline',
#   'james',
#   'comey',
#   'role',
#   'recalls'],
#  ['edgar',
#   'hoover',
#   'its',
#   'bizarre',
#   'headline',
#   'james',
#   'comey',
#   'role',
#   'recalls',
#   'hoover'],
#  ['hoover',
#   'its',
#   'bizarre',
#   'headline',
#   'james',
#   'comey',
#   'role',
#   'recalls',
#   'hoover',
#   's'],
#  ['its',
#   'bizarre',
#   'headline',
#   'james',
#   'comey',
#   'role',
#   'recalls',
#   'hoover',
#   's',
#   'fbi'],
#  ['bizarre',
#   'headline',
#   'james',
#   'comey',
#   'role',
#   'recalls',
#   'hoover',
#   's',
#   'fbi',
#   'fairly'],
#  ['headline',
#   'james',
#   'comey',
#   'role',
#   'recalls',
#   'hoover',
#   's',
#   'fbi',
#   'fairly',
#   'or'],
#  ['james',
#   'comey',
#   'role',
#   'recalls',
#   'hoover',
#   's',
#   'fbi',
#   'fairly',
#   'or',
#   'not'],
#  ['comey',
#   'role',
#   'recalls',
#   'hoover',
#   's',
#   'fbi',
#   'fairly',
#   'or',
#   'not',
#   'practically'],
#  ['role',
#   'recalls',
#   'hoover',
#   's',
#   'fbi',
#   'fairly',
#   'or',
#   'not',
#   'practically',
#   'admits'],
#  ['recalls',
#   'hoover',
#   's',
#   'fbi',
#   'fairly',
#   'or',
#   'not',
#   'practically',
#   'admits',
#   'up'],
#  ['hoover',
#   's',
#   'fbi',
#   'fairly',
#   'or',
#   'not',
#   'practically',
#   'admits',
#   'up',
#   'front'],
#  ['s',
#   'fbi',
#   'fairly',
#   'or',
#   'not',
#   'practically',
#   'admits',
#   'up',
#   'front',
#   'that'],
#  ['fbi',
#   'fairly',
#   'or',
#   'not',
#   'practically',
#   'admits',
#   'up',
#   'front',
#   'that',
#   'it'],
#  ['fairly',
#   'or',
#   'not',
#   'practically',
#   'admits',
#   'up',
#   'front',
#   'that',
#   'it',
#   's'],
#  ['or',
#   'not',
#   'practically',
#   'admits',
#   'up',
#   'front',
#   'that',
#   'it',
#   's',
#   'spouting'],
#  ['not',
#   'practically',
#   'admits',
#   'up',
#   'front',
#   'that',
#   'it',
#   's',
#   'spouting',
#   'nonsense'],
#  ['practically',
#   'admits',
#   'up',
#   'front',
#   'that',
#   'it',
#   's',
#   'spouting',
#   'nonsense',
#   'the'],
#  ['admits',
#   'up',
#   'front',
#   'that',
#   'it',
#   's',
#   'spouting',
#   'nonsense',
#   'the',
#   'boston'],
#  ['up',
#   'front',
#   'that',
#   'it',
#   's',
#   'spouting',
#   'nonsense',
#   'the',
#   'boston',
#   'globe'],
#  ['front',
#   'that',
#   'it',
#   's',
#   'spouting',
#   'nonsense',
#   'the',
#   'boston',
#   'globe',
#   'has'],
#  ['that',
#   'it',
#   's',
#   'spouting',
#   'nonsense',
#   'the',
#   'boston',
#   'globe',
#   'has',
#   'published'],
#  ['it',
#   's',
#   'spouting',
#   'nonsense',
#   'the',
#   'boston',
#   'globe',
#   'has',
#   'published',
#   'a'],
#  ['s',
#   'spouting',
#   'nonsense',
#   'the',
#   'boston',
#   'globe',
#   'has',
#   'published',
#   'a',
#   'column'],
#  ['spouting',
#   'nonsense',
#   'the',
#   'boston',
#   'globe',
#   'has',
#   'published',
#   'a',
#   'column',
#   'calling'],
#  ['nonsense',
#   'the',
#   'boston',
#   'globe',
#   'has',
#   'published',
#   'a',
#   'column',
#   'calling',
#   'for'],
#  ['the',
#   'boston',
#   'globe',
#   'has',
#   'published',
#   'a',
#   'column',
#   'calling',
#   'for',
#   'comey'],
#  ['boston',
#   'globe',
#   'has',
#   'published',
#   'a',
#   'column',
#   'calling',
#   'for',
#   'comey',
#   's'],
#  ['globe',
#   'has',
#   'published',
#   'a',
#   'column',
#   'calling',
#   'for',
#   'comey',
#   's',
#   'resignation'],
#  ['has',
#   'published',
#   'a',
#   'column',
#   'calling',
#   'for',
#   'comey',
#   's',
#   'resignation',
#   'not'],
#  ['published',
#   'a',
#   'column',
#   'calling',
#   'for',
#   'comey',
#   's',
#   'resignation',
#   'not',
#   'to'],
#  ['a',
#   'column',
#   'calling',
#   'for',
#   'comey',
#   's',
#   'resignation',
#   'not',
#   'to',
#   'be'],
#  ['column',
#   'calling',
#   'for',
#   'comey',
#   's',
#   'resignation',
#   'not',
#   'to',
#   'be',
#   'outdone'],
#  ['calling',
#   'for',
#   'comey',
#   's',
#   'resignation',
#   'not',
#   'to',
#   'be',
#   'outdone',
#   'time'],
#  ['for',
#   'comey',
#   's',
#   'resignation',
#   'not',
#   'to',
#   'be',
#   'outdone',
#   'time',
#   'has'],
#  ['comey',
#   's',
#   'resignation',
#   'not',
#   'to',
#   'be',
#   'outdone',
#   'time',
#   'has',
#   'an'],
#  ['s',
#   'resignation',
#   'not',
#   'to',
#   'be',
#   'outdone',
#   'time',
#   'has',
#   'an',
#   'editorial'],
#  ['resignation',
#   'not',
#   'to',
#   'be',
#   'outdone',
#   'time',
#   'has',
#   'an',
#   'editorial',
#   'claiming'],
#  ['not',
#   'to',
#   'be',
#   'outdone',
#   'time',
#   'has',
#   'an',
#   'editorial',
#   'claiming',
#   'that'],
#  ['to',
#   'be',
#   'outdone',
#   'time',
#   'has',
#   'an',
#   'editorial',
#   'claiming',
#   'that',
#   'the'],
#  ['be',
#   'outdone',
#   'time',
#   'has',
#   'an',
#   'editorial',
#   'claiming',
#   'that',
#   'the',
#   'scandal'],
#  ['outdone',
#   'time',
#   'has',
#   'an',
#   'editorial',
#   'claiming',
#   'that',
#   'the',
#   'scandal',
#   'is'],
#  ['time',
#   'has',
#   'an',
#   'editorial',
#   'claiming',
#   'that',
#   'the',
#   'scandal',
#   'is',
#   'really'],
#  ['has',
#   'an',
#   'editorial',
#   'claiming',
#   'that',
#   'the',
#   'scandal',
#   'is',
#   'really',
#   'an'],
#  ['an',
#   'editorial',
#   'claiming',
#   'that',
#   'the',
#   'scandal',
#   'is',
#   'really',
#   'an',
#   'attack'],
#  ['editorial',
#   'claiming',
#   'that',
#   'the',
#   'scandal',
#   'is',
#   'really',
#   'an',
#   'attack',
#   'on'],
#  ['claiming',
#   'that',
#   'the',
#   'scandal',
#   'is',
#   'really',
#   'an',
#   'attack',
#   'on',
#   'all'],
#  ['that',
#   'the',
#   'scandal',
#   'is',
#   'really',
#   'an',
#   'attack',
#   'on',
#   'all',
#   'women'],
#  ['the',
#   'scandal',
#   'is',
#   'really',
#   'an',
#   'attack',
#   'on',
#   'all',
#   'women',
#   'james'],
#  ['scandal',
#   'is',
#   'really',
#   'an',
#   'attack',
#   'on',
#   'all',
#   'women',
#   'james',
#   'carville'],
#  ['is',
#   'really',
#   'an',
#   'attack',
#   'on',
#   'all',
#   'women',
#   'james',
#   'carville',
#   'appeared'],
#  ['really',
#   'an',
#   'attack',
#   'on',
#   'all',
#   'women',
#   'james',
#   'carville',
#   'appeared',
#   'on'],
#  ['an',
#   'attack',
#   'on',
#   'all',
#   'women',
#   'james',
#   'carville',
#   'appeared',
#   'on',
#   'msnbc'],
#  ['attack',
#   'on',
#   'all',
#   'women',
#   'james',
#   'carville',
#   'appeared',
#   'on',
#   'msnbc',
#   'to'],
#  ['on',
#   'all',
#   'women',
#   'james',
#   'carville',
#   'appeared',
#   'on',
#   'msnbc',
#   'to',
#   'remind'],
#  ['all',
#   'women',
#   'james',
#   'carville',
#   'appeared',
#   'on',
#   'msnbc',
#   'to',
#   'remind',
#   'everyone'],
#  ['women',
#   'james',
#   'carville',
#   'appeared',
#   'on',
#   'msnbc',
#   'to',
#   'remind',
#   'everyone',
#   'that'],
#  ['james',
#   'carville',
#   'appeared',
#   'on',
#   'msnbc',
#   'to',
#   'remind',
#   'everyone',
#   'that',
#   'he'],
#  ['carville',
#   'appeared',
#   'on',
#   'msnbc',
#   'to',
#   'remind',
#   'everyone',
#   'that',
#   'he',
#   'was'],
#  ['appeared',
#   'on',
#   'msnbc',
#   'to',
#   'remind',
#   'everyone',
#   'that',
#   'he',
#   'was',
#   'still'],
#  ['on',
#   'msnbc',
#   'to',
#   'remind',
#   'everyone',
#   'that',
#   'he',
#   'was',
#   'still',
#   'alive'],
#  ['msnbc',
#   'to',
#   'remind',
#   'everyone',
#   'that',
#   'he',
#   'was',
#   'still',
#   'alive',
#   'and'],
#  ['to',
#   'remind',
#   'everyone',
#   'that',
#   'he',
#   'was',
#   'still',
#   'alive',
#   'and',
#   'insane'],
#  ['remind',
#   'everyone',
#   'that',
#   'he',
#   'was',
#   'still',
#   'alive',
#   'and',
#   'insane',
#   'he'],
#  ['everyone',
#   'that',
#   'he',
#   'was',
#   'still',
#   'alive',
#   'and',
#   'insane',
#   'he',
#   'accused'],
#  ['that',
#   'he',
#   'was',
#   'still',
#   'alive',
#   'and',
#   'insane',
#   'he',
#   'accused',
#   'comey'],
#  ['he',
#   'was',
#   'still',
#   'alive',
#   'and',
#   'insane',
#   'he',
#   'accused',
#   'comey',
#   'of'],
#  ['was',
#   'still',
#   'alive',
#   'and',
#   'insane',
#   'he',
#   'accused',
#   'comey',
#   'of',
#   'coordinating'],
#  ['still',
#   'alive',
#   'and',
#   'insane',
#   'he',
#   'accused',
#   'comey',
#   'of',
#   'coordinating',
#   'with'],
#  ['alive',
#   'and',
#   'insane',
#   'he',
#   'accused',
#   'comey',
#   'of',
#   'coordinating',
#   'with',
#   'house'],
#  ['and',
#   'insane',
#   'he',
#   'accused',
#   'comey',
#   'of',
#   'coordinating',
#   'with',
#   'house',
#   'republicans'],
#  ['insane',
#   'he',
#   'accused',
#   'comey',
#   'of',
#   'coordinating',
#   'with',
#   'house',
#   'republicans',
#   'and'],
#  ['he',
#   'accused',
#   'comey',
#   'of',
#   'coordinating',
#   'with',
#   'house',
#   'republicans',
#   'and',
#   'the'],
#  ['accused',
#   'comey',
#   'of',
#   'coordinating',
#   'with',
#   'house',
#   'republicans',
#   'and',
#   'the',
#   'kgb'],
#  ['comey',
#   'of',
#   'coordinating',
#   'with',
#   'house',
#   'republicans',
#   'and',
#   'the',
#   'kgb',
#   'and'],
#  ['of',
#   'coordinating',
#   'with',
#   'house',
#   'republicans',
#   'and',
#   'the',
#   'kgb',
#   'and',
#   'you'],
#  ['coordinating',
#   'with',
#   'house',
#   'republicans',
#   'and',
#   'the',
#   'kgb',
#   'and',
#   'you',
#   'thought'],
#  ['with',
#   'house',
#   'republicans',
#   'and',
#   'the',
#   'kgb',
#   'and',
#   'you',
#   'thought',
#   'the'],
#  ['house',
#   'republicans',
#   'and',
#   'the',
#   'kgb',
#   'and',
#   'you',
#   'thought',
#   'the',
#   'vast'],
#  ['republicans',
#   'and',
#   'the',
#   'kgb',
#   'and',
#   'you',
#   'thought',
#   'the',
#   'vast',
#   'right'],
#  ['and',
#   'the',
#   'kgb',
#   'and',
#   'you',
#   'thought',
#   'the',
#   'vast',
#   'right',
#   'wing'],
#  ['the',
#   'kgb',
#   'and',
#   'you',
#   'thought',
#   'the',
#   'vast',
#   'right',
#   'wing',
#   'conspiracy'],
#  ['kgb',
#   'and',
#   'you',
#   'thought',
#   'the',
#   'vast',
#   'right',
#   'wing',
#   'conspiracy',
#   'was'],
#  ['and',
#   'you',
#   'thought',
#   'the',
#   'vast',
#   'right',
#   'wing',
#   'conspiracy',
#   'was',
#   'a'],
#  ['you',
#   'thought',
#   'the',
#   'vast',
#   'right',
#   'wing',
#   'conspiracy',
#   'was',
#   'a',
#   'stretch'],
#  ['thought',
#   'the',
#   'vast',
#   'right',
#   'wing',
#   'conspiracy',
#   'was',
#   'a',
#   'stretch',
#   'countless'],
#  ['the',
#   'vast',
#   'right',
#   'wing',
#   'conspiracy',
#   'was',
#   'a',
#   'stretch',
#   'countless',
#   'media'],
#  ['vast',
#   'right',
#   'wing',
#   'conspiracy',
#   'was',
#   'a',
#   'stretch',
#   'countless',
#   'media',
#   'stories'],
#  ['right',
#   'wing',
#   'conspiracy',
#   'was',
#   'a',
#   'stretch',
#   'countless',
#   'media',
#   'stories',
#   'charge'],
#  ['wing',
#   'conspiracy',
#   'was',
#   'a',
#   'stretch',
#   'countless',
#   'media',
#   'stories',
#   'charge',
#   'comey'],
#  ['conspiracy',
#   'was',
#   'a',
#   'stretch',
#   'countless',
#   'media',
#   'stories',
#   'charge',
#   'comey',
#   'with'],
#  ['was',
#   'a',
#   'stretch',
#   'countless',
#   'media',
#   'stories',
#   'charge',
#   'comey',
#   'with',
#   'violating'],
#  ['a',
#   'stretch',
#   'countless',
#   'media',
#   'stories',
#   'charge',
#   'comey',
#   'with',
#   'violating',
#   'procedure'],
#  ['stretch',
#   'countless',
#   'media',
#   'stories',
#   'charge',
#   'comey',
#   'with',
#   'violating',
#   'procedure',
#   'do'],
#  ['countless',
#   'media',
#   'stories',
#   'charge',
#   'comey',
#   'with',
#   'violating',
#   'procedure',
#   'do',
#   'you'],
#  ['media',
#   'stories',
#   'charge',
#   'comey',
#   'with',
#   'violating',
#   'procedure',
#   'do',
#   'you',
#   'know'],
#  ['stories',
#   'charge',
#   'comey',
#   'with',
#   'violating',
#   'procedure',
#   'do',
#   'you',
#   'know',
#   'what'],
#  ['charge',
#   'comey',
#   'with',
#   'violating',
#   'procedure',
#   'do',
#   'you',
#   'know',
#   'what',
#   's'],
#  ['comey',
#   'with',
#   'violating',
#   'procedure',
#   'do',
#   'you',
#   'know',
#   'what',
#   's',
#   'a'],
#  ['with',
#   'violating',
#   'procedure',
#   'do',
#   'you',
#   'know',
#   'what',
#   's',
#   'a',
#   'procedural'],
#  ['violating',
#   'procedure',
#   'do',
#   'you',
#   'know',
#   'what',
#   's',
#   'a',
#   'procedural',
#   'violation'],
#  ['procedure',
#   'do',
#   'you',
#   'know',
#   'what',
#   's',
#   'a',
#   'procedural',
#   'violation',
#   'emailing'],
#  ['do',
#   'you',
#   'know',
#   'what',
#   's',
#   'a',
#   'procedural',
#   'violation',
#   'emailing',
#   'classified'],
#  ['you',
#   'know',
#   'what',
#   's',
#   'a',
#   'procedural',
#   'violation',
#   'emailing',
#   'classified',
#   'information'],
#  ['know',
#   'what',
#   's',
#   'a',
#   'procedural',
#   'violation',
#   'emailing',
#   'classified',
#   'information',
#   'stored'],
#  ['what',
#   's',
#   'a',
#   'procedural',
#   'violation',
#   'emailing',
#   'classified',
#   'information',
#   'stored',
#   'on'],
#  ['s',
#   'a',
#   'procedural',
#   'violation',
#   'emailing',
#   'classified',
#   'information',
#   'stored',
#   'on',
#   'your'],
#  ['a',
#   'procedural',
#   'violation',
#   'emailing',
#   'classified',
#   'information',
#   'stored',
#   'on',
#   'your',
#   'bathroom'],
#  ['procedural',
#   'violation',
#   'emailing',
#   'classified',
#   'information',
#   'stored',
#   'on',
#   'your',
#   'bathroom',
#   'server'],
#  ['violation',
#   'emailing',
#   'classified',
#   'information',
#   'stored',
#   'on',
#   'your',
#   'bathroom',
#   'server',
#   'senator'],
#  ['emailing',
#   'classified',
#   'information',
#   'stored',
#   'on',
#   'your',
#   'bathroom',
#   'server',
#   'senator',
#   'harry'],
#  ['classified',
#   'information',
#   'stored',
#   'on',
#   'your',
#   'bathroom',
#   'server',
#   'senator',
#   'harry',
#   'reid'],
#  ['information',
#   'stored',
#   'on',
#   'your',
#   'bathroom',
#   'server',
#   'senator',
#   'harry',
#   'reid',
#   'has'],
#  ['stored',
#   'on',
#   'your',
#   'bathroom',
#   'server',
#   'senator',
#   'harry',
#   'reid',
#   'has',
#   'sent'],
#  ['on',
#   'your',
#   'bathroom',
#   'server',
#   'senator',
#   'harry',
#   'reid',
#   'has',
#   'sent',
#   'comey'],
#  ['your',
#   'bathroom',
#   'server',
#   'senator',
#   'harry',
#   'reid',
#   'has',
#   'sent',
#   'comey',
#   'a'],
#  ['bathroom',
#   'server',
#   'senator',
#   'harry',
#   'reid',
#   'has',
#   'sent',
#   'comey',
#   'a',
#   'letter'],
#  ['server',
#   'senator',
#   'harry',
#   'reid',
#   'has',
#   'sent',
#   'comey',
#   'a',
#   'letter',
#   'accusing'],
#  ['senator',
#   'harry',
#   'reid',
#   'has',
#   'sent',
#   'comey',
#   'a',
#   'letter',
#   'accusing',
#   'him'],
#  ['harry',
#   'reid',
#   'has',
#   'sent',
#   'comey',
#   'a',
#   'letter',
#   'accusing',
#   'him',
#   'of'],
#  ['reid',
#   'has',
#   'sent',
#   'comey',
#   'a',
#   'letter',
#   'accusing',
#   'him',
#   'of',
#   'violating'],
#  ['has',
#   'sent',
#   'comey',
#   'a',
#   'letter',
#   'accusing',
#   'him',
#   'of',
#   'violating',
#   'the'],
#  ['sent',
#   'comey',
#   'a',
#   'letter',
#   'accusing',
#   'him',
#   'of',
#   'violating',
#   'the',
#   'hatch'],
#  ['comey',
#   'a',
#   'letter',
#   'accusing',
#   'him',
#   'of',
#   'violating',
#   'the',
#   'hatch',
#   'act'],
#  ['a',
#   'letter',
#   'accusing',
#   'him',
#   'of',
#   'violating',
#   'the',
#   'hatch',
#   'act',
#   'the'],
#  ['letter',
#   'accusing',
#   'him',
#   'of',
#   'violating',
#   'the',
#   'hatch',
#   'act',
#   'the',
#   'hatch'],
#  ['accusing',
#   'him',
#   'of',
#   'violating',
#   'the',
#   'hatch',
#   'act',
#   'the',
#   'hatch',
#   'act'],
#  ['him',
#   'of',
#   'violating',
#   'the',
#   'hatch',
#   'act',
#   'the',
#   'hatch',
#   'act',
#   'is'],
#  ['of', 'violating', 'the', 'hatch', 'act', 'the', 'hatch', 'act', 'is', 'a'],
#  ['violating',
#   'the',
#   'hatch',
#   'act',
#   'the',
#   'hatch',
#   'act',
#   'is',
#   'a',
#   'nice'],
#  ['the', 'hatch', 'act', 'the', 'hatch', 'act', 'is', 'a', 'nice', 'idea'],
#  ['hatch', 'act', 'the', 'hatch', 'act', 'is', 'a', 'nice', 'idea', 'that'],
#  ['act', 'the', 'hatch', 'act', 'is', 'a', 'nice', 'idea', 'that', 'has'],
#  ['the', 'hatch', 'act', 'is', 'a', 'nice', 'idea', 'that', 'has', 'as'],
#  ['hatch', 'act', 'is', 'a', 'nice', 'idea', 'that', 'has', 'as', 'much'],
#  ['act', 'is', 'a', 'nice', 'idea', 'that', 'has', 'as', 'much', 'relevance'],
#  ['is', 'a', 'nice', 'idea', 'that', 'has', 'as', 'much', 'relevance', 'in'],
#  ['a', 'nice', 'idea', 'that', 'has', 'as', 'much', 'relevance', 'in', 'the'],
#  ['nice',
#   'idea',
#   'that',
#   'has',
#   'as',
#   'much',
#   'relevance',
#   'in',
#   'the',
#   'age'],
#  ['idea', 'that', 'has', 'as', 'much', 'relevance', 'in', 'the', 'age', 'of'],
#  ['that', 'has', 'as', 'much', 'relevance', 'in', 'the', 'age', 'of', 'obama'],
#  ['has', 'as', 'much', 'relevance', 'in', 'the', 'age', 'of', 'obama', 'as'],
#  ['as', 'much', 'relevance', 'in', 'the', 'age', 'of', 'obama', 'as', 'the'],
#  ['much',
#   'relevance',
#   'in',
#   'the',
#   'age',
#   'of',
#   'obama',
#   'as',
#   'the',
#   'tenth'],
#  ['relevance',
#   'in',
#   'the',
#   'age',
#   'of',
#   'obama',
#   'as',
#   'the',
#   'tenth',
#   'amendment'],
#  ['in', 'the', 'age', 'of', 'obama', 'as', 'the', 'tenth', 'amendment', 'but'],
#  ['the',
#   'age',
#   'of',
#   'obama',
#   'as',
#   'the',
#   'tenth',
#   'amendment',
#   'but',
#   'the'],
#  ['age',
#   'of',
#   'obama',
#   'as',
#   'the',
#   'tenth',
#   'amendment',
#   'but',
#   'the',
#   'cable'],
#  ['of',
#   'obama',
#   'as',
#   'the',
#   'tenth',
#   'amendment',
#   'but',
#   'the',
#   'cable',
#   'news'],
#  ['obama',
#   'as',
#   'the',
#   'tenth',
#   'amendment',
#   'but',
#   'the',
#   'cable',
#   'news',
#   'spectrum'],
#  ['as',
#   'the',
#   'tenth',
#   'amendment',
#   'but',
#   'the',
#   'cable',
#   'news',
#   'spectrum',
#   'quickly'],
#  ['the',
#   'tenth',
#   'amendment',
#   'but',
#   'the',
#   'cable',
#   'news',
#   'spectrum',
#   'quickly',
#   'filled'],
#  ['tenth',
#   'amendment',
#   'but',
#   'the',
#   'cable',
#   'news',
#   'spectrum',
#   'quickly',
#   'filled',
#   'with'],
#  ['amendment',
#   'but',
#   'the',
#   'cable',
#   'news',
#   'spectrum',
#   'quickly',
#   'filled',
#   'with',
#   'media'],
#  ['but',
#   'the',
#   'cable',
#   'news',
#   'spectrum',
#   'quickly',
#   'filled',
#   'with',
#   'media',
#   'hacks'],
#  ['the',
#   'cable',
#   'news',
#   'spectrum',
#   'quickly',
#   'filled',
#   'with',
#   'media',
#   'hacks',
#   'glancing'],
#  ['cable',
#   'news',
#   'spectrum',
#   'quickly',
#   'filled',
#   'with',
#   'media',
#   'hacks',
#   'glancing',
#   'at'],
#  ['news',
#   'spectrum',
#   'quickly',
#   'filled',
#   'with',
#   'media',
#   'hacks',
#   'glancing',
#   'at',
#   'the'],
#  ['spectrum',
#   'quickly',
#   'filled',
#   'with',
#   'media',
#   'hacks',
#   'glancing',
#   'at',
#   'the',
#   'wikipedia'],
#  ['quickly',
#   'filled',
#   'with',
#   'media',
#   'hacks',
#   'glancing',
#   'at',
#   'the',
#   'wikipedia',
#   'article'],
#  ['filled',
#   'with',
#   'media',
#   'hacks',
#   'glancing',
#   'at',
#   'the',
#   'wikipedia',
#   'article',
#   'on'],
#  ['with',
#   'media',
#   'hacks',
#   'glancing',
#   'at',
#   'the',
#   'wikipedia',
#   'article',
#   'on',
#   'the'],
#  ['media',
#   'hacks',
#   'glancing',
#   'at',
#   'the',
#   'wikipedia',
#   'article',
#   'on',
#   'the',
#   'hatch'],
#  ['hacks',
#   'glancing',
#   'at',
#   'the',
#   'wikipedia',
#   'article',
#   'on',
#   'the',
#   'hatch',
#   'act'],
#  ['glancing',
#   'at',
#   'the',
#   'wikipedia',
#   'article',
#   'on',
#   'the',
#   'hatch',
#   'act',
#   'under'],
#  ['at',
#   'the',
#   'wikipedia',
#   'article',
#   'on',
#   'the',
#   'hatch',
#   'act',
#   'under',
#   'the'],
#  ['the',
#   'wikipedia',
#   'article',
#   'on',
#   'the',
#   'hatch',
#   'act',
#   'under',
#   'the',
#   'table'],
#  ['wikipedia',
#   'article',
#   'on',
#   'the',
#   'hatch',
#   'act',
#   'under',
#   'the',
#   'table',
#   'while'],
#  ['article',
#   'on',
#   'the',
#   'hatch',
#   'act',
#   'under',
#   'the',
#   'table',
#   'while',
#   'accusing'],
#  ['on',
#   'the',
#   'hatch',
#   'act',
#   'under',
#   'the',
#   'table',
#   'while',
#   'accusing',
#   'the'],
#  ['the',
#   'hatch',
#   'act',
#   'under',
#   'the',
#   'table',
#   'while',
#   'accusing',
#   'the',
#   'fbi'],
#  ['hatch',
#   'act',
#   'under',
#   'the',
#   'table',
#   'while',
#   'accusing',
#   'the',
#   'fbi',
#   'director'],
#  ['act',
#   'under',
#   'the',
#   'table',
#   'while',
#   'accusing',
#   'the',
#   'fbi',
#   'director',
#   'of'],
#  ['under',
#   'the',
#   'table',
#   'while',
#   'accusing',
#   'the',
#   'fbi',
#   'director',
#   'of',
#   'one'],
#  ['the',
#   'table',
#   'while',
#   'accusing',
#   'the',
#   'fbi',
#   'director',
#   'of',
#   'one',
#   'of'],
#  ['table',
#   'while',
#   'accusing',
#   'the',
#   'fbi',
#   'director',
#   'of',
#   'one',
#   'of',
#   'the'],
#  ['while',
#   'accusing',
#   'the',
#   'fbi',
#   'director',
#   'of',
#   'one',
#   'of',
#   'the',
#   'most'],
#  ['accusing',
#   'the',
#   'fbi',
#   'director',
#   'of',
#   'one',
#   'of',
#   'the',
#   'most',
#   'awkward'],
#  ['the',
#   'fbi',
#   'director',
#   'of',
#   'one',
#   'of',
#   'the',
#   'most',
#   'awkward',
#   'conspiracies'],
#  ['fbi',
#   'director',
#   'of',
#   'one',
#   'of',
#   'the',
#   'most',
#   'awkward',
#   'conspiracies',
#   'against'],
#  ['director',
#   'of',
#   'one',
#   'of',
#   'the',
#   'most',
#   'awkward',
#   'conspiracies',
#   'against',
#   'hillary'],
#  ['of',
#   'one',
#   'of',
#   'the',
#   'most',
#   'awkward',
#   'conspiracies',
#   'against',
#   'hillary',
#   'ever'],
#  ['one',
#   'of',
#   'the',
#   'most',
#   'awkward',
#   'conspiracies',
#   'against',
#   'hillary',
#   'ever',
#   'if'],
#  ['of',
#   'the',
#   'most',
#   'awkward',
#   'conspiracies',
#   'against',
#   'hillary',
#   'ever',
#   'if',
#   'james'],
#  ['the',
#   'most',
#   'awkward',
#   'conspiracies',
#   'against',
#   'hillary',
#   'ever',
#   'if',
#   'james',
#   'comey'],
#  ['most',
#   'awkward',
#   'conspiracies',
#   'against',
#   'hillary',
#   'ever',
#   'if',
#   'james',
#   'comey',
#   'is'],
#  ['awkward',
#   'conspiracies',
#   'against',
#   'hillary',
#   'ever',
#   'if',
#   'james',
#   'comey',
#   'is',
#   'really'],
#  ['conspiracies',
#   'against',
#   'hillary',
#   'ever',
#   'if',
#   'james',
#   'comey',
#   'is',
#   'really',
#   'out'],
#  ['against',
#   'hillary',
#   'ever',
#   'if',
#   'james',
#   'comey',
#   'is',
#   'really',
#   'out',
#   'to'],
#  ['hillary',
#   'ever',
#   'if',
#   'james',
#   'comey',
#   'is',
#   'really',
#   'out',
#   'to',
#   'hurt'],
#  ['ever',
#   'if',
#   'james',
#   'comey',
#   'is',
#   'really',
#   'out',
#   'to',
#   'hurt',
#   'hillary'],
#  ['if',
#   'james',
#   'comey',
#   'is',
#   'really',
#   'out',
#   'to',
#   'hurt',
#   'hillary',
#   'he'],
#  ['james',
#   'comey',
#   'is',
#   'really',
#   'out',
#   'to',
#   'hurt',
#   'hillary',
#   'he',
#   'picked'],
#  ['comey',
#   'is',
#   'really',
#   'out',
#   'to',
#   'hurt',
#   'hillary',
#   'he',
#   'picked',
#   'one'],
#  ['is',
#   'really',
#   'out',
#   'to',
#   'hurt',
#   'hillary',
#   'he',
#   'picked',
#   'one',
#   'hell'],
#  ['really',
#   'out',
#   'to',
#   'hurt',
#   'hillary',
#   'he',
#   'picked',
#   'one',
#   'hell',
#   'of'],
#  ['out', 'to', 'hurt', 'hillary', 'he', 'picked', 'one', 'hell', 'of', 'a'],
#  ['to',
#   'hurt',
#   'hillary',
#   'he',
#   'picked',
#   'one',
#   'hell',
#   'of',
#   'a',
#   'strange'],
#  ['hurt',
#   'hillary',
#   'he',
#   'picked',
#   'one',
#   'hell',
#   'of',
#   'a',
#   'strange',
#   'way'],
#  ['hillary', 'he', 'picked', 'one', 'hell', 'of', 'a', 'strange', 'way', 'to'],
#  ['he', 'picked', 'one', 'hell', 'of', 'a', 'strange', 'way', 'to', 'do'],
#  ['picked', 'one', 'hell', 'of', 'a', 'strange', 'way', 'to', 'do', 'it'],
#  ['one', 'hell', 'of', 'a', 'strange', 'way', 'to', 'do', 'it', 'not'],
#  ['hell', 'of', 'a', 'strange', 'way', 'to', 'do', 'it', 'not', 'too'],
#  ['of', 'a', 'strange', 'way', 'to', 'do', 'it', 'not', 'too', 'long'],
#  ['a', 'strange', 'way', 'to', 'do', 'it', 'not', 'too', 'long', 'ago'],
#  ['strange',
#   'way',
#   'to',
#   'do',
#   'it',
#   'not',
#   'too',
#   'long',
#   'ago',
#   'democrats'],
#  ['way', 'to', 'do', 'it', 'not', 'too', 'long', 'ago', 'democrats', 'were'],
#  ['to',
#   'do',
#   'it',
#   'not',
#   'too',
#   'long',
#   'ago',
#   'democrats',
#   'were',
#   'breathing'],
#  ['do',
#   'it',
#   'not',
#   'too',
#   'long',
#   'ago',
#   'democrats',
#   'were',
#   'breathing',
#   'a'],
#  ['it',
#   'not',
#   'too',
#   'long',
#   'ago',
#   'democrats',
#   'were',
#   'breathing',
#   'a',
#   'sigh'],
#  ['not',
# ...
#  ['to',
#   'reveal',
#   'about',
#   'her',
#   'during',
#   'the',
#   'original',
#   'fbi',
#   'investigation',
#   'hillary'],
#  ['reveal',
#   'about',
#   'her',
#   'during',
#   'the',
#   'original',
#   'fbi',
#   'investigation',
#   'hillary',
#   'clinton'],
#  ['about',
#   'her',
#   'during',
#   'the',
#   'original',
#   'fbi',
#   'investigation',
#   'hillary',
#   'clinton',
#   'was'],
#  ['her',
#   'during',
#   'the',
#   'original',
#   'fbi',
#   'investigation',
#   'hillary',
#   'clinton',
#   'was',
#   'confident'],
#  ['during',
#   'the',
#   'original',
#   'fbi',
#   'investigation',
#   'hillary',
#   'clinton',
#   'was',
#   'confident',
#   'that'],
#  ['the',
#   'original',
#   'fbi',
#   'investigation',
#   'hillary',
#   'clinton',
#   'was',
#   'confident',
#   'that',
#   'she'],
#  ['original',
#   'fbi',
#   'investigation',
#   'hillary',
#   'clinton',
#   'was',
#   'confident',
#   'that',
#   'she',
#   'could'],
#  ['fbi',
#   'investigation',
#   'hillary',
#   'clinton',
#   'was',
#   'confident',
#   'that',
#   'she',
#   'could',
#   'ride'],
#  ['investigation',
#   'hillary',
#   'clinton',
#   'was',
#   'confident',
#   'that',
#   'she',
#   'could',
#   'ride',
#   'it'],
#  ['hillary',
#   'clinton',
#   'was',
#   'confident',
#   'that',
#   'she',
#   'could',
#   'ride',
#   'it',
#   'out'],
#  ['clinton',
#   'was',
#   'confident',
#   'that',
#   'she',
#   'could',
#   'ride',
#   'it',
#   'out',
#   'and'],
#  ['was',
#   'confident',
#   'that',
#   'she',
#   'could',
#   'ride',
#   'it',
#   'out',
#   'and',
#   'she'],
#  ['confident',
#   'that',
#   'she',
#   'could',
#   'ride',
#   'it',
#   'out',
#   'and',
#   'she',
#   'had'],
#  ['that', 'she', 'could', 'ride', 'it', 'out', 'and', 'she', 'had', 'good'],
#  ['she', 'could', 'ride', 'it', 'out', 'and', 'she', 'had', 'good', 'reason'],
#  ['could', 'ride', 'it', 'out', 'and', 'she', 'had', 'good', 'reason', 'for'],
#  ['ride',
#   'it',
#   'out',
#   'and',
#   'she',
#   'had',
#   'good',
#   'reason',
#   'for',
#   'believing'],
#  ['it',
#   'out',
#   'and',
#   'she',
#   'had',
#   'good',
#   'reason',
#   'for',
#   'believing',
#   'that'],
#  ['out',
#   'and',
#   'she',
#   'had',
#   'good',
#   'reason',
#   'for',
#   'believing',
#   'that',
#   'but'],
#  ['and',
#   'she',
#   'had',
#   'good',
#   'reason',
#   'for',
#   'believing',
#   'that',
#   'but',
#   'that'],
#  ['she',
#   'had',
#   'good',
#   'reason',
#   'for',
#   'believing',
#   'that',
#   'but',
#   'that',
#   'hillary'],
#  ['had',
#   'good',
#   'reason',
#   'for',
#   'believing',
#   'that',
#   'but',
#   'that',
#   'hillary',
#   'clinton'],
#  ['good',
#   'reason',
#   'for',
#   'believing',
#   'that',
#   'but',
#   'that',
#   'hillary',
#   'clinton',
#   'is'],
#  ['reason',
#   'for',
#   'believing',
#   'that',
#   'but',
#   'that',
#   'hillary',
#   'clinton',
#   'is',
#   'gone'],
#  ['for',
#   'believing',
#   'that',
#   'but',
#   'that',
#   'hillary',
#   'clinton',
#   'is',
#   'gone',
#   'in'],
#  ['believing',
#   'that',
#   'but',
#   'that',
#   'hillary',
#   'clinton',
#   'is',
#   'gone',
#   'in',
#   'her'],
#  ['that',
#   'but',
#   'that',
#   'hillary',
#   'clinton',
#   'is',
#   'gone',
#   'in',
#   'her',
#   'place'],
#  ['but',
#   'that',
#   'hillary',
#   'clinton',
#   'is',
#   'gone',
#   'in',
#   'her',
#   'place',
#   'is'],
#  ['that', 'hillary', 'clinton', 'is', 'gone', 'in', 'her', 'place', 'is', 'a'],
#  ['hillary',
#   'clinton',
#   'is',
#   'gone',
#   'in',
#   'her',
#   'place',
#   'is',
#   'a',
#   'paranoid'],
#  ['clinton',
#   'is',
#   'gone',
#   'in',
#   'her',
#   'place',
#   'is',
#   'a',
#   'paranoid',
#   'wreck'],
#  ['is',
#   'gone',
#   'in',
#   'her',
#   'place',
#   'is',
#   'a',
#   'paranoid',
#   'wreck',
#   'within'],
#  ['gone', 'in', 'her', 'place', 'is', 'a', 'paranoid', 'wreck', 'within', 'a'],
#  ['in',
#   'her',
#   'place',
#   'is',
#   'a',
#   'paranoid',
#   'wreck',
#   'within',
#   'a',
#   'short'],
#  ['her',
#   'place',
#   'is',
#   'a',
#   'paranoid',
#   'wreck',
#   'within',
#   'a',
#   'short',
#   'space'],
#  ['place',
#   'is',
#   'a',
#   'paranoid',
#   'wreck',
#   'within',
#   'a',
#   'short',
#   'space',
#   'of'],
#  ['is',
#   'a',
#   'paranoid',
#   'wreck',
#   'within',
#   'a',
#   'short',
#   'space',
#   'of',
#   'time'],
#  ['a',
#   'paranoid',
#   'wreck',
#   'within',
#   'a',
#   'short',
#   'space',
#   'of',
#   'time',
#   'the'],
#  ['paranoid',
#   'wreck',
#   'within',
#   'a',
#   'short',
#   'space',
#   'of',
#   'time',
#   'the',
#   'positive'],
#  ['wreck',
#   'within',
#   'a',
#   'short',
#   'space',
#   'of',
#   'time',
#   'the',
#   'positive',
#   'clinton'],
#  ['within',
#   'a',
#   'short',
#   'space',
#   'of',
#   'time',
#   'the',
#   'positive',
#   'clinton',
#   'campaign'],
#  ['a',
#   'short',
#   'space',
#   'of',
#   'time',
#   'the',
#   'positive',
#   'clinton',
#   'campaign',
#   'promising'],
#  ['short',
#   'space',
#   'of',
#   'time',
#   'the',
#   'positive',
#   'clinton',
#   'campaign',
#   'promising',
#   'to'],
#  ['space',
#   'of',
#   'time',
#   'the',
#   'positive',
#   'clinton',
#   'campaign',
#   'promising',
#   'to',
#   'unite'],
#  ['of',
#   'time',
#   'the',
#   'positive',
#   'clinton',
#   'campaign',
#   'promising',
#   'to',
#   'unite',
#   'the'],
#  ['time',
#   'the',
#   'positive',
#   'clinton',
#   'campaign',
#   'promising',
#   'to',
#   'unite',
#   'the',
#   'country'],
#  ['the',
#   'positive',
#   'clinton',
#   'campaign',
#   'promising',
#   'to',
#   'unite',
#   'the',
#   'country',
#   'has'],
#  ['positive',
#   'clinton',
#   'campaign',
#   'promising',
#   'to',
#   'unite',
#   'the',
#   'country',
#   'has',
#   'been'],
#  ['clinton',
#   'campaign',
#   'promising',
#   'to',
#   'unite',
#   'the',
#   'country',
#   'has',
#   'been',
#   'replaced'],
#  ['campaign',
#   'promising',
#   'to',
#   'unite',
#   'the',
#   'country',
#   'has',
#   'been',
#   'replaced',
#   'by'],
#  ['promising',
#   'to',
#   'unite',
#   'the',
#   'country',
#   'has',
#   'been',
#   'replaced',
#   'by',
#   'a'],
#  ['to',
#   'unite',
#   'the',
#   'country',
#   'has',
#   'been',
#   'replaced',
#   'by',
#   'a',
#   'desperate'],
#  ['unite',
#   'the',
#   'country',
#   'has',
#   'been',
#   'replaced',
#   'by',
#   'a',
#   'desperate',
#   'and'],
#  ['the',
#   'country',
#   'has',
#   'been',
#   'replaced',
#   'by',
#   'a',
#   'desperate',
#   'and',
#   'flailing'],
#  ['country',
#   'has',
#   'been',
#   'replaced',
#   'by',
#   'a',
#   'desperate',
#   'and',
#   'flailing',
#   'operation'],
#  ['has',
#   'been',
#   'replaced',
#   'by',
#   'a',
#   'desperate',
#   'and',
#   'flailing',
#   'operation',
#   'that'],
#  ['been',
#   'replaced',
#   'by',
#   'a',
#   'desperate',
#   'and',
#   'flailing',
#   'operation',
#   'that',
#   'has'],
#  ['replaced',
#   'by',
#   'a',
#   'desperate',
#   'and',
#   'flailing',
#   'operation',
#   'that',
#   'has',
#   'focused'],
#  ['by',
#   'a',
#   'desperate',
#   'and',
#   'flailing',
#   'operation',
#   'that',
#   'has',
#   'focused',
#   'all'],
#  ['a',
#   'desperate',
#   'and',
#   'flailing',
#   'operation',
#   'that',
#   'has',
#   'focused',
#   'all',
#   'its'],
#  ['desperate',
#   'and',
#   'flailing',
#   'operation',
#   'that',
#   'has',
#   'focused',
#   'all',
#   'its',
#   'energy'],
#  ['and',
#   'flailing',
#   'operation',
#   'that',
#   'has',
#   'focused',
#   'all',
#   'its',
#   'energy',
#   'on'],
#  ['flailing',
#   'operation',
#   'that',
#   'has',
#   'focused',
#   'all',
#   'its',
#   'energy',
#   'on',
#   'fighting'],
#  ['operation',
#   'that',
#   'has',
#   'focused',
#   'all',
#   'its',
#   'energy',
#   'on',
#   'fighting',
#   'the'],
#  ['that',
#   'has',
#   'focused',
#   'all',
#   'its',
#   'energy',
#   'on',
#   'fighting',
#   'the',
#   'fbi'],
#  ['has',
#   'focused',
#   'all',
#   'its',
#   'energy',
#   'on',
#   'fighting',
#   'the',
#   'fbi',
#   'there'],
#  ['focused',
#   'all',
#   'its',
#   'energy',
#   'on',
#   'fighting',
#   'the',
#   'fbi',
#   'there',
#   's'],
#  ['all',
#   'its',
#   'energy',
#   'on',
#   'fighting',
#   'the',
#   'fbi',
#   'there',
#   's',
#   'only'],
#  ['its',
#   'energy',
#   'on',
#   'fighting',
#   'the',
#   'fbi',
#   'there',
#   's',
#   'only',
#   'one'],
#  ['energy',
#   'on',
#   'fighting',
#   'the',
#   'fbi',
#   'there',
#   's',
#   'only',
#   'one',
#   'reason'],
#  ['on',
#   'fighting',
#   'the',
#   'fbi',
#   'there',
#   's',
#   'only',
#   'one',
#   'reason',
#   'for'],
#  ['fighting',
#   'the',
#   'fbi',
#   'there',
#   's',
#   'only',
#   'one',
#   'reason',
#   'for',
#   'such'],
#  ['the',
#   'fbi',
#   'there',
#   's',
#   'only',
#   'one',
#   'reason',
#   'for',
#   'such',
#   'bizarre'],
#  ['fbi',
#   'there',
#   's',
#   'only',
#   'one',
#   'reason',
#   'for',
#   'such',
#   'bizarre',
#   'behavior'],
#  ['there',
#   's',
#   'only',
#   'one',
#   'reason',
#   'for',
#   'such',
#   'bizarre',
#   'behavior',
#   'the'],
#  ['s',
#   'only',
#   'one',
#   'reason',
#   'for',
#   'such',
#   'bizarre',
#   'behavior',
#   'the',
#   'clinton'],
#  ['only',
#   'one',
#   'reason',
#   'for',
#   'such',
#   'bizarre',
#   'behavior',
#   'the',
#   'clinton',
#   'campaign'],
#  ['one',
#   'reason',
#   'for',
#   'such',
#   'bizarre',
#   'behavior',
#   'the',
#   'clinton',
#   'campaign',
#   'has'],
#  ['reason',
#   'for',
#   'such',
#   'bizarre',
#   'behavior',
#   'the',
#   'clinton',
#   'campaign',
#   'has',
#   'decided'],
#  ['for',
#   'such',
#   'bizarre',
#   'behavior',
#   'the',
#   'clinton',
#   'campaign',
#   'has',
#   'decided',
#   'that'],
#  ['such',
#   'bizarre',
#   'behavior',
#   'the',
#   'clinton',
#   'campaign',
#   'has',
#   'decided',
#   'that',
#   'an'],
#  ['bizarre',
#   'behavior',
#   'the',
#   'clinton',
#   'campaign',
#   'has',
#   'decided',
#   'that',
#   'an',
#   'fbi'],
#  ['behavior',
#   'the',
#   'clinton',
#   'campaign',
#   'has',
#   'decided',
#   'that',
#   'an',
#   'fbi',
#   'investigation'],
#  ['the',
#   'clinton',
#   'campaign',
#   'has',
#   'decided',
#   'that',
#   'an',
#   'fbi',
#   'investigation',
#   'of'],
#  ['clinton',
#   'campaign',
#   'has',
#   'decided',
#   'that',
#   'an',
#   'fbi',
#   'investigation',
#   'of',
#   'the'],
#  ['campaign',
#   'has',
#   'decided',
#   'that',
#   'an',
#   'fbi',
#   'investigation',
#   'of',
#   'the',
#   'latest'],
#  ['has',
#   'decided',
#   'that',
#   'an',
#   'fbi',
#   'investigation',
#   'of',
#   'the',
#   'latest',
#   'batch'],
#  ['decided',
#   'that',
#   'an',
#   'fbi',
#   'investigation',
#   'of',
#   'the',
#   'latest',
#   'batch',
#   'of'],
#  ['that',
#   'an',
#   'fbi',
#   'investigation',
#   'of',
#   'the',
#   'latest',
#   'batch',
#   'of',
#   'emails'],
#  ['an',
#   'fbi',
#   'investigation',
#   'of',
#   'the',
#   'latest',
#   'batch',
#   'of',
#   'emails',
#   'poses'],
#  ['fbi',
#   'investigation',
#   'of',
#   'the',
#   'latest',
#   'batch',
#   'of',
#   'emails',
#   'poses',
#   'a'],
#  ['investigation',
#   'of',
#   'the',
#   'latest',
#   'batch',
#   'of',
#   'emails',
#   'poses',
#   'a',
#   'threat'],
#  ['of',
#   'the',
#   'latest',
#   'batch',
#   'of',
#   'emails',
#   'poses',
#   'a',
#   'threat',
#   'to'],
#  ['the',
#   'latest',
#   'batch',
#   'of',
#   'emails',
#   'poses',
#   'a',
#   'threat',
#   'to',
#   'its'],
#  ['latest',
#   'batch',
#   'of',
#   'emails',
#   'poses',
#   'a',
#   'threat',
#   'to',
#   'its',
#   'survival'],
#  ['batch',
#   'of',
#   'emails',
#   'poses',
#   'a',
#   'threat',
#   'to',
#   'its',
#   'survival',
#   'and'],
#  ['of',
#   'emails',
#   'poses',
#   'a',
#   'threat',
#   'to',
#   'its',
#   'survival',
#   'and',
#   'so'],
#  ['emails',
#   'poses',
#   'a',
#   'threat',
#   'to',
#   'its',
#   'survival',
#   'and',
#   'so',
#   'it'],
#  ['poses', 'a', 'threat', 'to', 'its', 'survival', 'and', 'so', 'it', 's'],
#  ['a', 'threat', 'to', 'its', 'survival', 'and', 'so', 'it', 's', 'gone'],
#  ['threat', 'to', 'its', 'survival', 'and', 'so', 'it', 's', 'gone', 'all'],
#  ['to', 'its', 'survival', 'and', 'so', 'it', 's', 'gone', 'all', 'in'],
#  ['its', 'survival', 'and', 'so', 'it', 's', 'gone', 'all', 'in', 'on'],
#  ['survival', 'and', 'so', 'it', 's', 'gone', 'all', 'in', 'on', 'fighting'],
#  ['and', 'so', 'it', 's', 'gone', 'all', 'in', 'on', 'fighting', 'the'],
#  ['so', 'it', 's', 'gone', 'all', 'in', 'on', 'fighting', 'the', 'fbi'],
#  ['it', 's', 'gone', 'all', 'in', 'on', 'fighting', 'the', 'fbi', 'it'],
#  ['s', 'gone', 'all', 'in', 'on', 'fighting', 'the', 'fbi', 'it', 's'],
#  ['gone', 'all', 'in', 'on', 'fighting', 'the', 'fbi', 'it', 's', 'an'],
#  ['all',
#   'in',
#   'on',
#   'fighting',
#   'the',
#   'fbi',
#   'it',
#   's',
#   'an',
#   'unprecedented'],
#  ['in',
#   'on',
#   'fighting',
#   'the',
#   'fbi',
#   'it',
#   's',
#   'an',
#   'unprecedented',
#   'step'],
#  ['on',
#   'fighting',
#   'the',
#   'fbi',
#   'it',
#   's',
#   'an',
#   'unprecedented',
#   'step',
#   'born'],
#  ['fighting',
#   'the',
#   'fbi',
#   'it',
#   's',
#   'an',
#   'unprecedented',
#   'step',
#   'born',
#   'of'],
#  ['the',
#   'fbi',
#   'it',
#   's',
#   'an',
#   'unprecedented',
#   'step',
#   'born',
#   'of',
#   'fear'],
#  ['fbi', 'it', 's', 'an', 'unprecedented', 'step', 'born', 'of', 'fear', 'it'],
#  ['it', 's', 'an', 'unprecedented', 'step', 'born', 'of', 'fear', 'it', 's'],
#  ['s', 'an', 'unprecedented', 'step', 'born', 'of', 'fear', 'it', 's', 'hard'],
#  ['an',
#   'unprecedented',
#   'step',
#   'born',
#   'of',
#   'fear',
#   'it',
#   's',
#   'hard',
#   'to'],
#  ['unprecedented',
#   'step',
#   'born',
#   'of',
#   'fear',
#   'it',
#   's',
#   'hard',
#   'to',
#   'know'],
#  ['step', 'born', 'of', 'fear', 'it', 's', 'hard', 'to', 'know', 'whether'],
#  ['born', 'of', 'fear', 'it', 's', 'hard', 'to', 'know', 'whether', 'that'],
#  ['of', 'fear', 'it', 's', 'hard', 'to', 'know', 'whether', 'that', 'fear'],
#  ['fear', 'it', 's', 'hard', 'to', 'know', 'whether', 'that', 'fear', 'is'],
#  ['it',
#   's',
#   'hard',
#   'to',
#   'know',
#   'whether',
#   'that',
#   'fear',
#   'is',
#   'justified'],
#  ['s',
#   'hard',
#   'to',
#   'know',
#   'whether',
#   'that',
#   'fear',
#   'is',
#   'justified',
#   'but'],
#  ['hard',
#   'to',
#   'know',
#   'whether',
#   'that',
#   'fear',
#   'is',
#   'justified',
#   'but',
#   'the'],
#  ['to',
#   'know',
#   'whether',
#   'that',
#   'fear',
#   'is',
#   'justified',
#   'but',
#   'the',
#   'existence'],
#  ['know',
#   'whether',
#   'that',
#   'fear',
#   'is',
#   'justified',
#   'but',
#   'the',
#   'existence',
#   'of'],
#  ['whether',
#   'that',
#   'fear',
#   'is',
#   'justified',
#   'but',
#   'the',
#   'existence',
#   'of',
#   'that'],
#  ['that',
#   'fear',
#   'is',
#   'justified',
#   'but',
#   'the',
#   'existence',
#   'of',
#   'that',
#   'fear'],
#  ['fear',
#   'is',
#   'justified',
#   'but',
#   'the',
#   'existence',
#   'of',
#   'that',
#   'fear',
#   'already'],
#  ['is',
#   'justified',
#   'but',
#   'the',
#   'existence',
#   'of',
#   'that',
#   'fear',
#   'already',
#   'tells'],
#  ['justified',
#   'but',
#   'the',
#   'existence',
#   'of',
#   'that',
#   'fear',
#   'already',
#   'tells',
#   'us'],
#  ['but',
#   'the',
#   'existence',
#   'of',
#   'that',
#   'fear',
#   'already',
#   'tells',
#   'us',
#   'a'],
#  ['the',
#   'existence',
#   'of',
#   'that',
#   'fear',
#   'already',
#   'tells',
#   'us',
#   'a',
#   'whole'],
#  ['existence',
#   'of',
#   'that',
#   'fear',
#   'already',
#   'tells',
#   'us',
#   'a',
#   'whole',
#   'lot'],
#  ['of',
#   'that',
#   'fear',
#   'already',
#   'tells',
#   'us',
#   'a',
#   'whole',
#   'lot',
#   'clinton'],
#  ['that',
#   'fear',
#   'already',
#   'tells',
#   'us',
#   'a',
#   'whole',
#   'lot',
#   'clinton',
#   'loyalists'],
#  ['fear',
#   'already',
#   'tells',
#   'us',
#   'a',
#   'whole',
#   'lot',
#   'clinton',
#   'loyalists',
#   'rigged'],
#  ['already',
#   'tells',
#   'us',
#   'a',
#   'whole',
#   'lot',
#   'clinton',
#   'loyalists',
#   'rigged',
#   'the'],
#  ['tells',
#   'us',
#   'a',
#   'whole',
#   'lot',
#   'clinton',
#   'loyalists',
#   'rigged',
#   'the',
#   'old'],
#  ['us',
#   'a',
#   'whole',
#   'lot',
#   'clinton',
#   'loyalists',
#   'rigged',
#   'the',
#   'old',
#   'investigation'],
#  ['a',
#   'whole',
#   'lot',
#   'clinton',
#   'loyalists',
#   'rigged',
#   'the',
#   'old',
#   'investigation',
#   'they'],
#  ['whole',
#   'lot',
#   'clinton',
#   'loyalists',
#   'rigged',
#   'the',
#   'old',
#   'investigation',
#   'they',
#   'knew'],
#  ['lot',
#   'clinton',
#   'loyalists',
#   'rigged',
#   'the',
#   'old',
#   'investigation',
#   'they',
#   'knew',
#   'the'],
#  ['clinton',
#   'loyalists',
#   'rigged',
#   'the',
#   'old',
#   'investigation',
#   'they',
#   'knew',
#   'the',
#   'outcome'],
#  ['loyalists',
#   'rigged',
#   'the',
#   'old',
#   'investigation',
#   'they',
#   'knew',
#   'the',
#   'outcome',
#   'ahead'],
#  ['rigged',
#   'the',
#   'old',
#   'investigation',
#   'they',
#   'knew',
#   'the',
#   'outcome',
#   'ahead',
#   'of'],
#  ['the',
#   'old',
#   'investigation',
#   'they',
#   'knew',
#   'the',
#   'outcome',
#   'ahead',
#   'of',
#   'time'],
#  ['old',
#   'investigation',
#   'they',
#   'knew',
#   'the',
#   'outcome',
#   'ahead',
#   'of',
#   'time',
#   'as'],
#  ['investigation',
#   'they',
#   'knew',
#   'the',
#   'outcome',
#   'ahead',
#   'of',
#   'time',
#   'as',
#   'well'],
#  ['they', 'knew', 'the', 'outcome', 'ahead', 'of', 'time', 'as', 'well', 'as'],
#  ['knew', 'the', 'outcome', 'ahead', 'of', 'time', 'as', 'well', 'as', 'they'],
#  ['the', 'outcome', 'ahead', 'of', 'time', 'as', 'well', 'as', 'they', 'knew'],
#  ['outcome', 'ahead', 'of', 'time', 'as', 'well', 'as', 'they', 'knew', 'the'],
#  ['ahead', 'of', 'time', 'as', 'well', 'as', 'they', 'knew', 'the', 'debate'],
#  ...]

# %%
X = np.zeros((len(inp_words), n_words, len(unique_tokens)), dtype=bool)
y = np.zeros((len(nxt_words), len(unique_tokens)), dtype=bool)

# %%
y
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
for i , words in enumerate(inp_words):
    for j, word in enumerate(words):
        X[i,j , unique_token_index[word]]=1
    y[i, unique_token_index[nxt_words[i]]]=1

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(n_words, len(unique_tokens)), return_sequences=True))
model.add(LSTM(128))
model.add(Dense(len(unique_tokens)))
model.add(Activation("softmax"))

# %%
model.compile(loss="categorical_crossentropy", optimizer=RMSprop(learning_rate=0.01),metrics=["accuracy"])
model.fit(X,y, batch_size=128, epochs=30, shuffle=True)
# Out:
# Epoch 1/30
# 28/28 [==============================] - 8s 101ms/step - loss: 6.0731 - accuracy: 0.0432
# Epoch 2/30
# 28/28 [==============================] - 3s 102ms/step - loss: 5.8030 - accuracy: 0.0618
# Epoch 3/30
# 28/28 [==============================] - 3s 101ms/step - loss: 5.7310 - accuracy: 0.0618
# Epoch 4/30
# 28/28 [==============================] - 3s 117ms/step - loss: 5.6324 - accuracy: 0.0624
# Epoch 5/30
# 28/28 [==============================] - 3s 113ms/step - loss: 5.4460 - accuracy: 0.0638
# Epoch 6/30
# 28/28 [==============================] - 3s 111ms/step - loss: 5.0677 - accuracy: 0.0798
# Epoch 7/30
# 28/28 [==============================] - 3s 111ms/step - loss: 4.5848 - accuracy: 0.1138
# Epoch 8/30
# 28/28 [==============================] - 3s 107ms/step - loss: 4.0134 - accuracy: 0.1639
# Epoch 9/30
# 28/28 [==============================] - 3s 106ms/step - loss: 3.3910 - accuracy: 0.2411
# Epoch 10/30
# 28/28 [==============================] - 3s 106ms/step - loss: 2.6836 - accuracy: 0.3624
# Epoch 11/30
# 28/28 [==============================] - 3s 106ms/step - loss: 2.0353 - accuracy: 0.5269
# Epoch 12/30
# 28/28 [==============================] - 3s 104ms/step - loss: 1.4415 - accuracy: 0.6922
# Epoch 13/30
# 28/28 [==============================] - 3s 105ms/step - loss: 0.8947 - accuracy: 0.8464
# Epoch 14/30
# 28/28 [==============================] - 3s 108ms/step - loss: 0.5903 - accuracy: 0.9150
# Epoch 15/30
# 28/28 [==============================] - 3s 112ms/step - loss: 0.3455 - accuracy: 0.9620
# Epoch 16/30
# 28/28 [==============================] - 3s 107ms/step - loss: 0.2107 - accuracy: 0.9771
# Epoch 17/30
# 28/28 [==============================] - 3s 108ms/step - loss: 0.1768 - accuracy: 0.9800
# Epoch 18/30
# 28/28 [==============================] - 3s 107ms/step - loss: 0.0531 - accuracy: 0.9977
# Epoch 19/30
# 28/28 [==============================] - 3s 108ms/step - loss: 0.1670 - accuracy: 0.9708
# Epoch 20/30
# 28/28 [==============================] - 3s 106ms/step - loss: 0.0257 - accuracy: 0.9991
# Epoch 21/30
# 28/28 [==============================] - 3s 108ms/step - loss: 0.1238 - accuracy: 0.9783
# Epoch 22/30
# 28/28 [==============================] - 3s 108ms/step - loss: 0.0127 - accuracy: 0.9991
# Epoch 23/30
# 28/28 [==============================] - 3s 111ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 24/30
# 28/28 [==============================] - 3s 109ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 25/30
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 26/30
# 28/28 [==============================] - 3s 120ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 27/30
# 28/28 [==============================] - 3s 110ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 28/30
# 28/28 [==============================] - 3s 105ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 29/30
# 28/28 [==============================] - 3s 107ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 30/30
# 28/28 [==============================] - 3s 105ms/step - loss: 0.0021 - accuracy: 1.0000

# %%
model.save("mrk1.h5")
# Out:
# C:\Users\Yousuf\Desktop\jar_mrk1\venv1\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model = load_model("mrk1.h5")

# %%
def predict_nxt(inp_txt, n_best):
    inp_txt = inp_txt.lower()
    X = np.zeros((1,n_words, len(unique_tokens)))
    for i, word in enumerate(inp_txt.split()):
        X[0,i,unique_token_index[word]]=1
    predictions = model.predict(X)[0]
    return np.argpartition(predictions, -n_best)[-n_best:]

# %%
poss = predict_nxt("He is bad and a",5)
# Out:
# 1/1 [==============================] - 0s 51ms/step

# %%
poss
# Out:
# array([640, 134, 283, 323,  27], dtype=int64)

# %%
print([unique_token[idx] for idx in poss])
# Out:
# ['james', 'and', 'hillary', 'he', 'this']

# %%
def generate_text(input_text,text_length, creativity =3):
    word_sequence = input_text.split()
    current = 0
    for _ in range(text_length) :
        sub_sequence = " ".join(tokenizer.tokenize(" ".join(word_sequence).lower())[current:current+n_words])
        try:
            choice = unique_tokens[random.choice(predict_nxt(sub_sequence, creativity))]
        except:
            choice = random.choice(unique_tokens)
        word_sequence.append(choice)
        current +=1
    return " ".join(word_sequence)

# %%
generate_text("He is a bad person and  ", 100, 5)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 'He is a bad person and filled ahead targeting stand moral after trump afraid any if if fear people agents fireworks her way down trump now rally fear has now went under under being this hour from of from he nothing after would than would he a a uncomfortable often would would not not it a was an fbi s was bigotry and way their that but else fear have when a election s s not not not to not the trump it whose assaulting through a his paul a election ryan hillary career not to just will an it s was unscathed after to when'
